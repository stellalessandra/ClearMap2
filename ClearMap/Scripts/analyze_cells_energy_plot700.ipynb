# %%
# !pip install odfpy
# !pip install seaborn
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yaml
from yaml import Loader
import numpy as np
import analyze_cells_energy as ace
import utils
from scipy.stats import ttest_ind

# %%
root_directory = '/home/stella/Documents/Torino/projects/'
experiment = 'SexualImprinting'
experimental_group = 'C57_MaleUrine_Exposure_cFos'
subjects = ace.list_subjects(root_directory)
data_directory = root_directory + experiment + '/' \
                + experimental_group + '/'

# %%
# load query file where we added volumes for each area
volumes = pd.read_csv("query_complete_with_volumes.csv")
volumes = ace.clean_volumes_database(volumes)

# %%
def load_subject(subject):
    df_mouse = pd.read_csv(data_directory + subject + '/cells.csv')
    df_mouse = ace.reformat_df_mouse(df=df_mouse)
    return df_mouse

# %%
subject = 'F1Control'

# %%
f1control = load_subject(subject)

# %%
f1control
# Out:
#       x_resampled  y_resampled  z_resampled  size  source           x  \
# 0            1718         4737           10    36    2373  140.678611
# 1            1758         4241           10    42    2181  136.263803
# 2            1672         4458           12    24    1826  131.253234
# 3            1826         4203           12    29    1850  142.307568
# 4            1843         4220           12    22    1652  144.297862
# ...           ...          ...          ...   ...     ...         ...
# 3127         2434         3382          730    30    3359  186.341369
# 3128         2569         3652          730    33    2274  205.632175
# 3129         2727         1147          730    42    3778  217.007073
# 3130         2727         5098          730    25    2357  258.875285
# 3131         2732         1153          730    24    3567  217.565713
#
#                y           z    id  \
# 0     337.107642   25.589814   367
# 1     298.309612   29.250393   158
# 2     316.092921   28.162763   158
# 3     294.714141   29.977053   158
# 4     295.899289   29.804121   158
# ...          ...         ...   ...
# 3127  228.359298  224.779737   701
# 3128  249.678232  225.268982   703
# 3129   33.169467  229.463498  1098
# 3130  376.417387  211.460680   910
# 3131   33.550315  229.468958  1098
#
#                                          area_name
# 0               Temporal association areas layer 1
# 1                  Ventral auditory area layer 2/3
# 2                  Ventral auditory area layer 2/3
# 3                  Ventral auditory area layer 2/3
# 4                  Ventral auditory area layer 2/3
# ...                                            ...
# 3127       Paraventricular nucleus of the thalamus
# 3128                           Nucleus of reuniens
# 3129  olfactory nerve layer of main olfactory bulb
# 3130                   Tegmental reticular nucleus
# 3131  olfactory nerve layer of main olfactory bulb
#
# [3132 rows x 10 columns]

# %%
df_cells_energy = ace.calculate_cells_energy_per_level(df_mouse=f1control, vol=volumes, level=8)

# %%
df_cells_energy
# Out:
#                             area  n_cells        energy
# 48             Fastigial nucleus        0      0.000000
# 49            Interposed nucleus        0      0.000000
# 50               Dentate nucleus        0      0.000000
# 51   Vestibulocerebellar nucleus        0      0.000000
# 88                     Claustrum       10  79656.608352
# ..                           ...      ...           ...
# 377           Nucleus prepositus        0      0.000000
# 378   Lateral vestibular nucleus        0      0.000000
# 379    Medial vestibular nucleus        0      0.000000
# 380    Spinal vestibular nucleus        0      0.000000
# 381  Superior vestibular nucleus        1  18846.974320
#
# [297 rows x 3 columns]

# %%
fig, axes = plt.subplots(1,3, figsize=[10,4])
sns.histplot(df_cells_energy[df_cells_energy.n_cells != 0]['n_cells'], ax=axes[0], edgecolor=None)
sns.histplot(df_cells_energy[df_cells_energy.energy != 0]['energy'], ax=axes[1], edgecolor=None)
sns.histplot(df_cells_energy[df_cells_energy.energy != 0]['energy'], ax=axes[2], log_scale=True, edgecolor=None)
axes[1].set_ylabel('')
axes[2].set_ylabel('')
fig.suptitle('Cells + energy distribution' + ' - ' + experiment+ ' - ' + experimental_group + ' - ' + subject)
# Out:
# Text(0.5, 0.98, 'Cells + energy distribution - SexualImprinting - C57_MaleUrine_Exposure_cFos - F1Control')

# %% [markdown]
# # TODOs
# - lista Aree
# - lista aree nulle
# - numero di cellule per area per topo / across mice
# - energy dist
# - t test across areas per topo unfam vs control - fam vs control - familiar vs unfam
# - rank numero di cellule per topo / across topi

# %% [markdown]
# # Analysis on C57

# %%
# TODO: this is barbaric but quick
dict_results_across_mice = {subject: ace.calculate_cells_energy_per_level(df_mouse=load_subject(subject), 
                                                                          vol=volumes, 
                                                                          level=8) for subject in subjects}

# %%
dict_results_across_mice['F10Control']
# Out:
#                             area  n_cells        energy
# 48             Fastigial nucleus        0      0.000000
# 49            Interposed nucleus        0      0.000000
# 50               Dentate nucleus        0      0.000000
# 51   Vestibulocerebellar nucleus        0      0.000000
# 88                     Claustrum        8  61309.100832
# ..                           ...      ...           ...
# 377           Nucleus prepositus        0      0.000000
# 378   Lateral vestibular nucleus        0      0.000000
# 379    Medial vestibular nucleus        0      0.000000
# 380    Spinal vestibular nucleus        0      0.000000
# 381  Superior vestibular nucleus        0      0.000000
#
# [297 rows x 3 columns]

# %%
for subject in subjects:
    df_sub = dict_results_across_mice[subject]
    fig, axes = plt.subplots(1,3, figsize=[10,4])
    sns.histplot(df_sub[df_sub.n_cells != 0]['n_cells'], ax=axes[0], edgecolor=None)
    sns.histplot(df_sub[df_sub.energy != 0]['energy'], ax=axes[1], edgecolor=None)
    sns.histplot(df_sub[df_sub.energy != 0]['energy'], ax=axes[2], log_scale=True, edgecolor=None)
    axes[1].set_ylabel('')
    axes[2].set_ylabel('')
    fig.suptitle('Cells + energy distribution' + ' - ' + experiment+ ' - ' + experimental_group + ' - ' + subject)

# %% [markdown]
# # Rank areas with highest cell count

# %%
df_cells_energy[df_cells_energy.n_cells != 0].sort_values(by=['n_cells'], ascending=False)
# Out:
#                             area  n_cells         energy
# 152                Piriform area      326  155180.879227
# 314                Dentate gyrus      185  151251.534339
# 149   Anterior olfactory nucleus      157  145717.177159
# 317              Entorhinal area      133   59659.523018
# 96           Inferior colliculus      114  146722.083455
# ..                           ...      ...            ...
# 238      Supratrigeminal nucleus        1   11982.156198
# 240  Motor nucleus of trigeminal        1   10751.863325
# 148     Accessory olfactory bulb        1    4315.889616
# 273    Lateral reticular nucleus        1    7208.136329
# 381  Superior vestibular nucleus        1   18846.974320
#
# [109 rows x 3 columns]

# %%
db_ranked_cells = {subject: dict_results_across_mice[subject][
    dict_results_across_mice[subject].n_cells != 0].sort_values(by=['n_cells'],
                                                                ascending=False) for subject in subjects}

# %%
subjects
# Out:
# ['F10Control',
#  'F6Unfam',
#  'F16Control',
#  'F8Unfam',
#  'F7Fam',
#  'F11Control',
#  'F15Fam',
#  'F13Fam',
#  'F1Control',
#  'F4Unfam',
#  'F5Fam',
#  'F2Unfam',
#  'F3Fam',
#  'F9Fam',
#  'F12Unfam',
#  'F14Unfam']

# %%
db_ranked_cells['F8Unfam'][0:30]
# Out:
#                                    area  n_cells        energy
# 147                 Main olfactory bulb      964  3.985122e+05
# 306                 Primary visual area      726  5.494924e+05
# 152                       Piriform area      695  3.532331e+05
# 169            Medial amygdalar nucleus      586  1.897410e+06
# 154             Cortical amygdalar area      575  1.186279e+06
# 157                        Caudoputamen      387  1.026409e+05
# 149          Anterior olfactory nucleus      361  3.578669e+05
# 92         Basomedial amygdalar nucleus      251  1.062672e+06
# 317                     Entorhinal area      242  1.126909e+05
# 314                       Dentate gyrus      186  1.792652e+05
# 307          Posterolateral visual area      183  1.363200e+06
# 312           Rostrolateral visual area      156  9.244840e+05
# 210           Lateral hypothalamic area      154  4.059303e+05
# 150                        Taenia tecta      150  5.433850e+05
# 206       Ventral premammillary nucleus      136  5.154997e+06
# 144                  Retrosplenial area      125  6.213529e+04
# 91        Basolateral amygdalar nucleus      124  3.524427e+05
# 305                 Lateral visual area      120  5.792477e+05
# 176  Bed nuclei of the stria terminalis      117  4.820951e+05
# 155             Piriform-amygdalar area      114  6.443958e+05
# 217                     Tuberal nucleus      114  1.417571e+06
# 93          Posterior amygdalar nucleus      107  6.420741e+05
# 297          Primary somatosensory area      100  2.600845e+04
# 204             Medial preoptic nucleus       94  1.450713e+06
# 89                 Endopiriform nucleus       92  1.460793e+05
# 191                Medial preoptic area       91  8.080715e+05
# 96                  Inferior colliculus       85  1.124063e+05
# 148            Accessory olfactory bulb       84  6.526532e+05
# 296                Secondary motor area       78  3.202731e+04
# 209      Posterior hypothalamic nucleus       78  2.872583e+05

# %% [markdown]
# # Rank areas with highest energy

# %%
db_ranked_energy = {subject: dict_results_across_mice[subject][
    dict_results_across_mice[subject].energy != 0].sort_values(by=['energy'],
                                                                ascending=False) for subject in subjects}

# %%
db_ranked_energy['F8Unfam'][0:30]
# Out:
#                                                   area  n_cells        energy
# 206                      Ventral premammillary nucleus      136  5.154997e+06
# 166       Bed nucleus of the accessory olfactory tract       21  4.204250e+06
# 193                     Posterodorsal preoptic nucleus        7  3.238480e+06
# 169                           Medial amygdalar nucleus      586  1.897410e+06
# 168                     Intercalated amygdalar nucleus       47  1.472243e+06
# 204                            Medial preoptic nucleus       94  1.450713e+06
# 217                                    Tuberal nucleus      114  1.417571e+06
# 307                         Posterolateral visual area      183  1.363200e+06
# 154                            Cortical amygdalar area      575  1.186279e+06
# 205                       Dorsal premammillary nucleus       22  1.063204e+06
# 92                        Basomedial amygdalar nucleus      251  1.062672e+06
# 189            Dorsomedial nucleus of the hypothalamus       59  9.587713e+05
# 196  Periventricular hypothalamic nucleus posterior...       37  9.579715e+05
# 208                  Ventromedial hypothalamic nucleus       77  9.462930e+05
# 312                          Rostrolateral visual area      156  9.244840e+05
# 191                               Medial preoptic area       91  8.080715e+05
# 348                                Parataenial nucleus       31  6.693929e+05
# 368                           Tuberomammillary nucleus       13  6.659905e+05
# 148                           Accessory olfactory bulb       84  6.526532e+05
# 155                            Piriform-amygdalar area      114  6.443958e+05
# 93                         Posterior amygdalar nucleus      107  6.420741e+05
# 305                                Lateral visual area      120  5.792477e+05
# 306                                Primary visual area      726  5.494924e+05
# 150                                       Taenia tecta      150  5.433850e+05
# 176                 Bed nuclei of the stria terminalis      117  4.820951e+05
# 367                            Supramammillary nucleus       40  4.322950e+05
# 198                            Subparaventricular zone        9  4.233751e+05
# 210                          Lateral hypothalamic area      154  4.059303e+05
# 147                                Main olfactory bulb      964  3.985122e+05
# 182                                 Supraoptic nucleus        3  3.587680e+05

# %% [markdown]
# # List areas with null cell count

# %%
db_null_count = {subject: dict_results_across_mice[subject][
    dict_results_across_mice[subject].n_cells == 0] for subject in subjects}

# %%
# make histogram of these
null_areas = [db_null_count[subjects[0]].area.values]
for subject in subjects[1:]:
    null_areas.append(db_null_count[subject].area.values)
null_areas = np.hstack(null_areas)
fig, ax = plt.subplots(1,1,figsize=(20,3))
pd.Series(null_areas).value_counts(sort=True).plot(kind='bar', axes=ax)
# plt.figure(figsize=(20,3))
# plt.hist(null_areas, bins=len())
# plt.xticks(rotation=90)
# Out:
# <AxesSubplot:>

# %%
# print areas that are null for all mice
df = pd.DataFrame(pd.Series(null_areas).value_counts(sort=False))
df.columns = ['counts']
df = df[df.counts == 16]
print(df.to_string())
# Out:
#                                                        counts
# Median eminence                                            16
# Submedial nucleus of the thalamus                          16
# Anterior hypothalamic area                                 16
# Intermediate geniculate nucleus                            16
# Suprageniculate nucleus                                    16
# Ventromedial preoptic nucleus                              16
# Rostral linear nucleus raphe                               16
# Dorsal terminal nucleus of the accessory optic tract       16
# Nucleus of Roller                                          16
# Peritrigeminal zone                                        16
# Granular lamina of the cochlear nuclei                     16
# Cochlear nucleus subpedunclular granular region            16
# Nucleus raphe obscurus                                     16
# Infracerebellar nucleus                                    16
# Bed nucleus of the anterior commissure                     16
# Nucleus circularis                                         16
# Parabigeminal nucleus                                      16
# Hippocampo-amygdalar transition area                       16
# Postrhinal area                                            16
# Paranigral nucleus                                         16
# Nucleus raphe pontis                                       16
# Edinger-Westphal nucleus                                   16
# Prosubiculum                                               16
# Anterior tegmental nucleus                                 16
# Substantia nigra lateral part                              16
# Medial terminal nucleus of the accessory optic tract       16
# Crus 1                                                     16
# Paracentral nucleus                                        16
# Lingula (I)                                                16
# Laterointermediate area                                    16
# Crus 2                                                     16
# Pineal body                                                16
# Paratrochlear nucleus                                      16
# Efferent vestibular nucleus                                16
# Subgeniculate nucleus                                      16
# Nucleus z                                                  16
# Lobules IV-V                                               16
# External cuneate nucleus                                   16
# Dentate nucleus                                            16
# Induseum griseum                                           16
# Parasolitary nucleus                                       16
# Ethmoid nucleus of the thalamus                            16
# Lateral strip of striatum                                  16
# Posterior intralaminar thalamic nucleus                    16
# Nucleus prepositus                                         16
# Superior salivatory nucleus                                16
# Interstitial nucleus of the vestibular nerve               16
# Lobule II                                                  16
# Subcommissural organ                                       16
# Lobule III                                                 16
# Lateral mammillary nucleus                                 16
# Peripeduncular nucleus                                     16
# Nucleus sagulum                                            16
# Perifornical nucleus                                       16
# Lateral terminal nucleus of the accessory optic tract      16
# Retroethmoid nucleus                                       16
# Trochlear nucleus                                          16
# Posterodorsal tegmental nucleus                            16
# Paratrigeminal nucleus                                     16
# Lobule IV                                                  16
# Parvicellular motor 5 nucleus                              16
# Midbrain trigeminal nucleus                                16
# Lateral tegmental nucleus                                  16
# Locus ceruleus                                             16
# Intercollicular nucleus                                    16
# Accessory abducens nucleus                                 16
# Posterior triangular thalamic nucleus                      16
# Accessory trigeminal nucleus                               16
# Lobule V                                                   16
# Pontine reticular nucleus ventral part                     16
# Accessory facial motor nucleus                             16
# Efferent cochlear group                                    16
# Suprachiasmatic preoptic nucleus                           16
# Ectorhinal area                                            16
# Anterior area                                              16
# Sublaterodorsal nucleus                                    16
# Medial accesory oculomotor nucleus                         16
# Lateral vestibular nucleus                                 16
# Nucleus intercalatus                                       16
# Vestibulocerebellar nucleus                                16
# Intertrigeminal nucleus                                    16
# Xiphoid thalamic nucleus                                   16
# Nucleus y                                                  16
# Paramedian reticular nucleus                               16
# Linear nucleus of the medulla                              16
# Preparasubthalamic nucleus                                 16
# Area prostriata                                            16

# %% [markdown]
# # List areas with no volume

# %%
db_null_volume = {subject: dict_results_across_mice[subject][
    dict_results_across_mice[subject]['energy'].isnull()] for subject in subjects}

# %%
# make histogram of these
null_volume = [db_null_volume[subjects[0]].area.values]
for subject in subjects[1:]:
    null_volume.append(db_null_volume[subject].area.values)
null_volume = np.hstack(null_volume)
fig, ax = plt.subplots(1,1,figsize=(20,3))
pd.Series(null_volume).value_counts(sort=True).plot(kind='bar', axes=ax)
# Out:
# <AxesSubplot:>

# %%
# print areas that are null for all mice
df = pd.DataFrame(pd.Series(null_volume).value_counts(sort=False))
df.columns = ['counts']
df = df[df.counts == 16]
print(df.to_string())
# Out:
#                                                  counts
# Nucleus z                                            16
# Pontine reticular nucleus ventral part               16
# Anterior hypothalamic area                           16
# Nucleus circularis                                   16
# Substantia nigra lateral part                        16
# Paramedian reticular nucleus                         16
# Efferent cochlear group                              16
# Suprachiasmatic preoptic nucleus                     16
# Superior salivatory nucleus                          16
# Lateral strip of striatum                            16
# Lateral tegmental nucleus                            16
# Lobule IV                                            16
# Pineal body                                          16
# Efferent vestibular nucleus                          16
# Interstitial nucleus of the vestibular nerve         16
# Granular lamina of the cochlear nuclei               16
# Nucleus intercalatus                                 16
# Intercollicular nucleus                              16
# Accessory abducens nucleus                           16
# Cochlear nucleus subpedunclular granular region      16
# Lobule V                                             16
# Retroethmoid nucleus                                 16

# %% [markdown]
# # Divide mice into experimental groups: FAM/UNFAM/CONTROL

# %%
experimental_groups = utils.divide_in_exp_groups(list_subjects=subjects)
experimental_groups
# Out:
# {'Control': ['F10Control', 'F16Control', 'F11Control', 'F1Control'],
#  'Unfam': ['F6Unfam', 'F8Unfam', 'F4Unfam', 'F2Unfam', 'F12Unfam', 'F14Unfam'],
#  'Fam': ['F7Fam', 'F15Fam', 'F13Fam', 'F5Fam', 'F3Fam', 'F9Fam']}

# %% [markdown]
# # Calculate cell count across experimental groups

# %%
def calculate_value_across_groups(experimental_groups, dict_results_across_mice, value='n_cells'):
    """
    Value can either be n_cells or energy
    """
    df_control = pd.DataFrame()
    df_fam = pd.DataFrame()
    df_unfam = pd.DataFrame()
    for subject in experimental_groups['Control']:
        df_control['area'] = dict_results_across_mice[subject]['area']
        df_control[subject] = dict_results_across_mice[subject][value]
    for subject in experimental_groups['Fam']:
        df_fam['area'] = dict_results_across_mice[subject]['area']
        df_fam[subject] = dict_results_across_mice[subject][value]
    for subject in experimental_groups['Unfam']:
        df_unfam['area'] = dict_results_across_mice[subject]['area']
        df_unfam[subject] = dict_results_across_mice[subject][value]
    return df_control, df_fam, df_unfam

# %%
df_control_cell_count, df_fam_cell_count, df_unfam_cell_count = \
calculate_value_across_groups(experimental_groups=experimental_groups, 
                              dict_results_across_mice=dict_results_across_mice, 
                              value='n_cells')

# %%
df_control_cell_count
# Out:
#                             area  F10Control  F16Control  F11Control  \
# 48             Fastigial nucleus           0           0           0
# 49            Interposed nucleus           0           0           0
# 50               Dentate nucleus           0           0           0
# 51   Vestibulocerebellar nucleus           0           0           0
# 88                     Claustrum           8           0           0
# ..                           ...         ...         ...         ...
# 377           Nucleus prepositus           0           0           0
# 378   Lateral vestibular nucleus           0           0           0
# 379    Medial vestibular nucleus           0           0           1
# 380    Spinal vestibular nucleus           0           0           0
# 381  Superior vestibular nucleus           0           0           0
#
#      F1Control
# 48           0
# 49           0
# 50           0
# 51           0
# 88          10
# ..         ...
# 377          0
# 378          0
# 379          0
# 380          0
# 381          1
#
# [297 rows x 5 columns]

# %%
df_fam_cell_count
# Out:
#                             area  F7Fam  F15Fam  F13Fam  F5Fam  F3Fam  F9Fam
# 48             Fastigial nucleus      0       0       0      0      0      0
# 49            Interposed nucleus      0       0       0      1      0      0
# 50               Dentate nucleus      0       0       0      0      0      0
# 51   Vestibulocerebellar nucleus      0       0       0      0      0      0
# 88                     Claustrum      6       0       2      7      1     16
# ..                           ...    ...     ...     ...    ...    ...    ...
# 377           Nucleus prepositus      0       0       0      0      0      0
# 378   Lateral vestibular nucleus      0       0       0      0      0      0
# 379    Medial vestibular nucleus      0       0       0      0      0      0
# 380    Spinal vestibular nucleus      0       0       0      0      0      0
# 381  Superior vestibular nucleus      0       0       0      0      0      0
#
# [297 rows x 7 columns]

# %%
df_unfam_cell_count
# Out:
#                             area  F6Unfam  F8Unfam  F4Unfam  F2Unfam  \
# 48             Fastigial nucleus        1        0        0        0
# 49            Interposed nucleus        0        0        0        0
# 50               Dentate nucleus        0        0        0        0
# 51   Vestibulocerebellar nucleus        0        0        0        0
# 88                     Claustrum       20       14        3       25
# ..                           ...      ...      ...      ...      ...
# 377           Nucleus prepositus        0        0        0        0
# 378   Lateral vestibular nucleus        0        0        0        0
# 379    Medial vestibular nucleus        0        0        0        0
# 380    Spinal vestibular nucleus        0        0        0        2
# 381  Superior vestibular nucleus        0        0        4        0
#
#      F12Unfam  F14Unfam
# 48          0         0
# 49          0         0
# 50          0         0
# 51          0         0
# 88          9         0
# ..        ...       ...
# 377         0         0
# 378         0         0
# 379         0         0
# 380         0         0
# 381         0         0
#
# [297 rows x 7 columns]

# %% [markdown]
# ## Calculate t-tests across groups per area

# %%
def ttest_across_groups(df_control, df_fam, df_unfam):
    df_ttest = pd.DataFrame(columns=['area', 'pval_Control_vs_Fam', 
                                     'pval_Control_vs_Unfam', 'pval_Fam_vs_Unfam'])
    df_ttest['area'] = df_control['area']
    # loop over areas
    for area in df_control['area'].values:
        # compare control and fam
        pval_control_fam = ttest_ind(df_control[df_control['area'] == area].values[0][1:],
             df_fam[df_fam['area'] == area].values[0][1:])
        # assign pvalue to dataframe
        df_ttest['pval_Control_vs_Fam'][df_ttest.loc[df_ttest['area'] == area].index[0]] = pval_control_fam[1]

        # compare control and unfam
        pval_control_unfam = ttest_ind(df_control[df_control['area'] == area].values[0][1:],
             df_unfam[df_unfam['area'] == area].values[0][1:])
        # assign pvalue to dataframe
        df_ttest['pval_Control_vs_Unfam'][df_ttest.loc[df_ttest['area'] == area].index[0]] = pval_control_unfam[1]

        # compare fam and unfam
        pval_fam_unfam = ttest_ind(df_fam[df_fam['area'] == area].values[0][1:],
             df_unfam[df_unfam['area'] == area].values[0][1:])
        # assign pvalue to dataframe
        df_ttest['pval_Fam_vs_Unfam'][df_ttest.loc[df_ttest['area'] == area].index[0]] = pval_fam_unfam[1]
    return df_ttest

# %%
df_ttest_ncells = ttest_across_groups(df_control=df_control_cell_count, 
                               df_fam=df_fam_cell_count, 
                               df_unfam=df_unfam_cell_count)
df_ttest_ncells
# Out:
#                             area pval_Control_vs_Fam pval_Control_vs_Unfam  \
# 48             Fastigial nucleus                 NaN              0.446813
# 49            Interposed nucleus            0.446813                   NaN
# 50               Dentate nucleus                 NaN                   NaN
# 51   Vestibulocerebellar nucleus                 NaN                   NaN
# 88                     Claustrum            0.825978              0.209279
# ..                           ...                 ...                   ...
# 377           Nucleus prepositus                 NaN                   NaN
# 378   Lateral vestibular nucleus                 NaN                   NaN
# 379    Medial vestibular nucleus            0.241504              0.241504
# 380    Spinal vestibular nucleus                 NaN              0.446813
# 381  Superior vestibular nucleus            0.241504              0.639657
#
#     pval_Fam_vs_Unfam
# 48           0.340893
# 49           0.340893
# 50                NaN
# 51                NaN
# 88           0.191603
# ..                ...
# 377               NaN
# 378               NaN
# 379               NaN
# 380          0.340893
# 381          0.340893
#
# [297 rows x 4 columns]

# %%
# remove rows corresponding to area that have zero cell count across all experimental groups
df_ttest_not_null_ncells = df_ttest_ncells.dropna(axis=0,
                                   how='all',
                                   subset=['pval_Control_vs_Fam',
                                          'pval_Control_vs_Unfam',
                                          'pval_Fam_vs_Unfam'])
df_ttest_not_null_ncells
# Out:
#                             area pval_Control_vs_Fam pval_Control_vs_Unfam  \
# 48             Fastigial nucleus                 NaN              0.446813
# 49            Interposed nucleus            0.446813                   NaN
# 88                     Claustrum            0.825978              0.209279
# 89          Endopiriform nucleus            0.286819              0.198355
# 90     Lateral amygdalar nucleus             0.85626              0.368446
# ..                           ...                 ...                   ...
# 373              Cuneate nucleus            0.149578              0.203895
# 374              Gracile nucleus            0.446813                   NaN
# 379    Medial vestibular nucleus            0.241504              0.241504
# 380    Spinal vestibular nucleus                 NaN              0.446813
# 381  Superior vestibular nucleus            0.241504              0.639657
#
#     pval_Fam_vs_Unfam
# 48           0.340893
# 49           0.340893
# 88           0.191603
# 89           0.442438
# 90           0.305405
# ..                ...
# 373          0.340893
# 374          0.340893
# 379               NaN
# 380          0.340893
# 381          0.340893
#
# [210 rows x 4 columns]

# %%
# sort dataframe pvalues of control vs fam and pick the first 20
df_ttest_not_null_ncells.sort_values(by='pval_Control_vs_Fam')[['area', 'pval_Control_vs_Fam']][0:20].set_index('area')
# Out:
#                                                    pval_Control_vs_Fam
# area
# Medial preoptic nucleus                                     0.00262871
# Cortical amygdalar area                                       0.006737
# Medial amygdalar nucleus                                     0.0086571
# Bed nuclei of the stria terminalis                           0.0208919
# Bed nucleus of the accessory olfactory tract                 0.0239483
# Tuberal nucleus                                              0.0263196
# Intercalated amygdalar nucleus                               0.0320833
# Fasciola cinerea                                             0.0352652
# Ventromedial hypothalamic nucleus                            0.0380056
# Posterior auditory area                                      0.0429612
# Periventricular hypothalamic nucleus posterior ...           0.0471805
# Ventral premammillary nucleus                                  0.05616
# Primary auditory area                                        0.0567393
# Red nucleus                                                  0.0598379
# Accessory olfactory bulb                                     0.0642675
# Piriform-amygdalar area                                      0.0697634
# Posterior amygdalar nucleus                                  0.0770724
# Perirhinal area                                              0.0794759
# Nucleus of the brachium of the inferior colliculus            0.082826
# Globus pallidus internal segment                              0.082826

# %%
# sort dataframe pvalues of control vs unfam and pick the first 20
df_ttest_not_null_ncells.sort_values(by='pval_Control_vs_Unfam')[['area', 'pval_Control_vs_Unfam']][0:20].set_index('area')
# Out:
#                                                    pval_Control_vs_Unfam
# area
# Cortical amygdalar area                                       0.00460707
# Medial preoptic nucleus                                       0.00881791
# Periventricular hypothalamic nucleus posterior ...              0.010056
# Medial amygdalar nucleus                                       0.0103031
# Bed nuclei of the stria terminalis                             0.0182939
# Posterior amygdalar nucleus                                    0.0210745
# Ventromedial hypothalamic nucleus                              0.0221525
# Nucleus of the solitary tract                                  0.0231052
# Anterior amygdalar area                                         0.028484
# Anteroventral periventricular nucleus                          0.0353303
# Piriform-amygdalar area                                        0.0380504
# Intercalated amygdalar nucleus                                 0.0475495
# Ventral premammillary nucleus                                  0.0509345
# Posterodorsal preoptic nucleus                                 0.0517342
# Red nucleus                                                    0.0598379
# Septohippocampal nucleus                                       0.0598379
# Posterior hypothalamic nucleus                                 0.0601869
# Paraventricular hypothalamic nucleus                           0.0670319
# Basomedial amygdalar nucleus                                   0.0676149
# Tuberal nucleus                                                0.0678116

# %%
# sort dataframe pvalues of fam vs unfam and pick the first 20
df_ttest_not_null_ncells.sort_values(by='pval_Fam_vs_Unfam')[['area', 'pval_Fam_vs_Unfam']][0:20].set_index('area')
# Out:
#                                         pval_Fam_vs_Unfam
# area
# Fasciola cinerea                                0.0101196
# Simple lobule                                   0.0134385
# Posterior hypothalamic nucleus                  0.0153221
# Supramammillary nucleus                         0.0217184
# Posterodorsal preoptic nucleus                   0.024491
# Medial preoptic nucleus                         0.0343519
# Medial mammillary nucleus                        0.050643
# Dorsal premammillary nucleus                    0.0527809
# Dorsomedial nucleus of the hypothalamus          0.056834
# Nucleus x                                       0.0646153
# Substantia nigra reticular part                  0.073388
# Medial septal complex                           0.0750118
# Subparafascicular nucleus                       0.0808863
# Postpiriform transition area                    0.0843155
# Bed nuclei of the stria terminalis              0.0850836
# Anterior hypothalamic nucleus                   0.0855484
# Supratrigeminal nucleus                         0.0868676
# Subparaventricular zone                          0.103391
# Nucleus of reuniens                              0.109665
# Nucleus incertus                                 0.111386

# %% [markdown]
# ## Code to calculate cross corr matrix

# %%
def cross_corr(df):
    # remove areas where no cells have been detected in any mouse
    # and remove rows with all nans
    corr_matrix = df.set_index('area').loc[
        ~(df.set_index('area')==0).all(axis=1)].dropna(axis=0).T.corr(method='pearson')
    return corr_matrix

# %% [markdown]
# ## Calculate cross corr across groups per area on cell count

# %%
corr_matrix_control_ncells = cross_corr(df_control_cell_count)
corr_matrix_control_ncells
# Out:
# area                           Claustrum  Endopiriform nucleus  \
# area
# Claustrum                       1.000000              0.528328
# Endopiriform nucleus            0.528328              1.000000
# Lateral amygdalar nucleus       0.508278              0.901157
# Basolateral amygdalar nucleus   0.585957              0.978855
# Basomedial amygdalar nucleus    0.775286              0.944978
# ...                                  ...                   ...
# Supramammillary nucleus         0.443607              0.992486
# Tuberomammillary nucleus        0.443607              0.992486
# Cuneate nucleus                -0.505813             -0.125078
# Medial vestibular nucleus      -0.570352             -0.317595
# Superior vestibular nucleus     0.697097             -0.238197
#
# area                           Lateral amygdalar nucleus  \
# area
# Claustrum                                       0.508278
# Endopiriform nucleus                            0.901157
# Lateral amygdalar nucleus                       1.000000
# Basolateral amygdalar nucleus                   0.966279
# Basomedial amygdalar nucleus                    0.879597
# ...                                                  ...
# Supramammillary nucleus                         0.857537
# Tuberomammillary nucleus                        0.857537
# Cuneate nucleus                                 0.233095
# Medial vestibular nucleus                       0.050443
# Superior vestibular nucleus                    -0.151330
#
# area                           Basolateral amygdalar nucleus  \
# area
# Claustrum                                           0.585957
# Endopiriform nucleus                                0.978855
# Lateral amygdalar nucleus                           0.966279
# Basolateral amygdalar nucleus                       1.000000
# Basomedial amygdalar nucleus                        0.958172
# ...                                                      ...
# Supramammillary nucleus                             0.949334
# Tuberomammillary nucleus                            0.949334
# Cuneate nucleus                                    -0.005463
# Medial vestibular nucleus                          -0.195069
# Superior vestibular nucleus                        -0.143050
#
# area                           Basomedial amygdalar nucleus  \
# area
# Claustrum                                          0.775286
# Endopiriform nucleus                               0.944978
# Lateral amygdalar nucleus                          0.879597
# Basolateral amygdalar nucleus                      0.958172
# Basomedial amygdalar nucleus                       1.000000
# ...                                                     ...
# Supramammillary nucleus                            0.904158
# Tuberomammillary nucleus                           0.904158
# Cuneate nucleus                                   -0.255799
# Medial vestibular nucleus                         -0.424400
# Superior vestibular nucleus                        0.092261
#
# area                           Posterior amygdalar nucleus  \
# area
# Claustrum                                         0.662651
# Endopiriform nucleus                              0.981181
# Lateral amygdalar nucleus                         0.930244
# Basolateral amygdalar nucleus                     0.991430
# Basomedial amygdalar nucleus                      0.985771
# ...                                                    ...
# Supramammillary nucleus                           0.950586
# Tuberomammillary nucleus                          0.950586
# Cuneate nucleus                                  -0.133109
# Medial vestibular nucleus                        -0.316862
# Superior vestibular nucleus                      -0.063372
#
# area                           Superior colliculus sensory related  \
# area
# Claustrum                                                 0.620920
# Endopiriform nucleus                                      0.875190
# Lateral amygdalar nucleus                                 0.988483
# Basolateral amygdalar nucleus                             0.955637
# Basomedial amygdalar nucleus                              0.903969
# ...                                                            ...
# Supramammillary nucleus                                   0.816497
# Tuberomammillary nucleus                                  0.816497
# Cuneate nucleus                                           0.171499
# Medial vestibular nucleus                                 0.000000
# Superior vestibular nucleus                               0.000000
#
# area                           Inferior colliculus  \
# area
# Claustrum                                 0.998259
# Endopiriform nucleus                      0.539758
# Lateral amygdalar nucleus                 0.542914
# Basolateral amygdalar nucleus             0.607139
# Basomedial amygdalar nucleus              0.785187
# ...                                            ...
# Supramammillary nucleus                   0.451422
# Tuberomammillary nucleus                  0.451422
# Cuneate nucleus                          -0.454127
# Medial vestibular nucleus                -0.522700
# Superior vestibular nucleus               0.689013
#
# area                           Nucleus of the brachium of the inferior colliculus  \
# area
# Claustrum                                                               0.959760
# Endopiriform nucleus                                                    0.269521
# Lateral amygdalar nucleus                                               0.289775
# Basolateral amygdalar nucleus                                           0.346362
# Basomedial amygdalar nucleus                                            0.568544
# ...                                                                          ...
# Supramammillary nucleus                                                 0.174078
# Tuberomammillary nucleus                                                0.174078
# Cuneate nucleus                                                        -0.511891
# Medial vestibular nucleus                                              -0.522233
# Superior vestibular nucleus                                             0.870388
#
# area                           Substantia nigra reticular part  ...  \
# area                                                            ...
# Claustrum                                            -0.570352  ...
# Endopiriform nucleus                                 -0.436694  ...
# Lateral amygdalar nucleus                            -0.756650  ...
# Basolateral amygdalar nucleus                        -0.611215  ...
# Basomedial amygdalar nucleus                         -0.572018  ...
# ...                                                        ...  ...
# Supramammillary nucleus                              -0.333333  ...
# Tuberomammillary nucleus                             -0.333333  ...
# Cuneate nucleus                                      -0.420084  ...
# Medial vestibular nucleus                            -0.333333  ...
# Superior vestibular nucleus                          -0.333333  ...
#
# area                           Intergeniculate leaflet of the lateral geniculate complex  \
# area
# Claustrum                                                              -0.109764
# Endopiriform nucleus                                                    0.584472
# Lateral amygdalar nucleus                                               0.786334
# Basolateral amygdalar nucleus                                           0.653213
# Basomedial amygdalar nucleus                                            0.415482
# ...                                                                          ...
# Supramammillary nucleus                                                 0.577350
# Tuberomammillary nucleus                                                0.577350
# Cuneate nucleus                                                         0.727607
# Medial vestibular nucleus                                               0.577350
# Superior vestibular nucleus                                            -0.577350
#
# area                           Ventral part of the lateral geniculate complex  \
# area
# Claustrum                                                            0.443607
# Endopiriform nucleus                                                 0.992486
# Lateral amygdalar nucleus                                            0.857537
# Basolateral amygdalar nucleus                                        0.949334
# Basomedial amygdalar nucleus                                         0.904158
# ...                                                                       ...
# Supramammillary nucleus                                              1.000000
# Tuberomammillary nucleus                                             1.000000
# Cuneate nucleus                                                     -0.140028
# Medial vestibular nucleus                                           -0.333333
# Superior vestibular nucleus                                         -0.333333
#
# area                           Medial habenula  Lateral habenula  \
# area
# Claustrum                             0.491171          0.697097
# Endopiriform nucleus                  0.998817         -0.238197
# Lateral amygdalar nucleus             0.908239         -0.151330
# Basolateral amygdalar nucleus         0.978464         -0.143050
# Basomedial amygdalar nucleus          0.930696          0.092261
# ...                                        ...               ...
# Supramammillary nucleus               0.993661         -0.333333
# Tuberomammillary nucleus              0.993661         -0.333333
# Cuneate nucleus                      -0.083484         -0.420084
# Medial vestibular nucleus            -0.278225         -0.333333
# Superior vestibular nucleus          -0.278225          1.000000
#
# area                           Medial mammillary nucleus  \
# area
# Claustrum                                       0.443607
# Endopiriform nucleus                            0.992486
# Lateral amygdalar nucleus                       0.857537
# Basolateral amygdalar nucleus                   0.949334
# Basomedial amygdalar nucleus                    0.904158
# ...                                                  ...
# Supramammillary nucleus                         1.000000
# Tuberomammillary nucleus                        1.000000
# Cuneate nucleus                                -0.140028
# Medial vestibular nucleus                      -0.333333
# Superior vestibular nucleus                    -0.333333
#
# area                           Supramammillary nucleus  \
# area
# Claustrum                                     0.443607
# Endopiriform nucleus                          0.992486
# Lateral amygdalar nucleus                     0.857537
# Basolateral amygdalar nucleus                 0.949334
# Basomedial amygdalar nucleus                  0.904158
# ...                                                ...
# Supramammillary nucleus                       1.000000
# Tuberomammillary nucleus                      1.000000
# Cuneate nucleus                              -0.140028
# Medial vestibular nucleus                    -0.333333
# Superior vestibular nucleus                  -0.333333
#
# area                           Tuberomammillary nucleus  Cuneate nucleus  \
# area
# Claustrum                                      0.443607        -0.505813
# Endopiriform nucleus                           0.992486        -0.125078
# Lateral amygdalar nucleus                      0.857537         0.233095
# Basolateral amygdalar nucleus                  0.949334        -0.005463
# Basomedial amygdalar nucleus                   0.904158        -0.255799
# ...                                                 ...              ...
# Supramammillary nucleus                        1.000000        -0.140028
# Tuberomammillary nucleus                       1.000000        -0.140028
# Cuneate nucleus                               -0.140028         1.000000
# Medial vestibular nucleus                     -0.333333         0.980196
# Superior vestibular nucleus                   -0.333333        -0.420084
#
# area                           Medial vestibular nucleus  \
# area
# Claustrum                                      -0.570352
# Endopiriform nucleus                           -0.317595
# Lateral amygdalar nucleus                       0.050443
# Basolateral amygdalar nucleus                  -0.195069
# Basomedial amygdalar nucleus                   -0.424400
# ...                                                  ...
# Supramammillary nucleus                        -0.333333
# Tuberomammillary nucleus                       -0.333333
# Cuneate nucleus                                 0.980196
# Medial vestibular nucleus                       1.000000
# Superior vestibular nucleus                    -0.333333
#
# area                           Superior vestibular nucleus
# area
# Claustrum                                         0.697097
# Endopiriform nucleus                             -0.238197
# Lateral amygdalar nucleus                        -0.151330
# Basolateral amygdalar nucleus                    -0.143050
# Basomedial amygdalar nucleus                      0.092261
# ...                                                    ...
# Supramammillary nucleus                          -0.333333
# Tuberomammillary nucleus                         -0.333333
# Cuneate nucleus                                  -0.420084
# Medial vestibular nucleus                        -0.333333
# Superior vestibular nucleus                       1.000000
#
# [159 rows x 159 columns]

# %%
corr_matrix_fam_ncells = cross_corr(df_fam_cell_count)
corr_matrix_fam_ncells
# Out:
# area                           Interposed nucleus  Claustrum  \
# area
# Interposed nucleus                       1.000000   0.137882
# Claustrum                                0.137882   1.000000
# Endopiriform nucleus                    -0.248545   0.920565
# Lateral amygdalar nucleus               -0.739076   0.381552
# Basolateral amygdalar nucleus           -0.459051   0.707988
# ...                                           ...        ...
# Supramammillary nucleus                 -0.392792  -0.234689
# Tuberomammillary nucleus                -0.447214  -0.472747
# Dorsal cochlear nucleus                 -0.316228   0.348817
# Ventral cochlear nucleus                 0.979796   0.084435
# Gracile nucleus                         -0.200000  -0.275764
#
# area                           Endopiriform nucleus  \
# area
# Interposed nucleus                        -0.248545
# Claustrum                                  0.920565
# Endopiriform nucleus                       1.000000
# Lateral amygdalar nucleus                  0.676987
# Basolateral amygdalar nucleus              0.904925
# ...                                             ...
# Supramammillary nucleus                   -0.036050
# Tuberomammillary nucleus                  -0.360525
# Dorsal cochlear nucleus                    0.425928
# Ventral cochlear nucleus                  -0.304404
# Gracile nucleus                           -0.248545
#
# area                           Lateral amygdalar nucleus  \
# area
# Interposed nucleus                             -0.739076
# Claustrum                                       0.381552
# Endopiriform nucleus                            0.676987
# Lateral amygdalar nucleus                       1.000000
# Basolateral amygdalar nucleus                   0.834153
# ...                                                  ...
# Supramammillary nucleus                         0.596359
# Tuberomammillary nucleus                       -0.140921
# Dorsal cochlear nucleus                         0.298940
# Ventral cochlear nucleus                       -0.799926
# Gracile nucleus                                -0.223442
#
# area                           Basolateral amygdalar nucleus  \
# area
# Interposed nucleus                                 -0.459051
# Claustrum                                           0.707988
# Endopiriform nucleus                                0.904925
# Lateral amygdalar nucleus                           0.834153
# Basolateral amygdalar nucleus                       1.000000
# ...                                                      ...
# Supramammillary nucleus                             0.254047
# Tuberomammillary nucleus                           -0.447978
# Dorsal cochlear nucleus                             0.284343
# Ventral cochlear nucleus                           -0.541934
# Gracile nucleus                                    -0.359669
#
# area                           Basomedial amygdalar nucleus  \
# area
# Interposed nucleus                                -0.396027
# Claustrum                                          0.814135
# Endopiriform nucleus                               0.962294
# Lateral amygdalar nucleus                          0.841440
# Basolateral amygdalar nucleus                      0.952746
# ...                                                     ...
# Supramammillary nucleus                            0.205478
# Tuberomammillary nucleus                          -0.376826
# Dorsal cochlear nucleus                            0.413008
# Ventral cochlear nucleus                          -0.472132
# Gracile nucleus                                   -0.332831
#
# area                           Posterior amygdalar nucleus  \
# area
# Interposed nucleus                               -0.411145
# Claustrum                                         0.715608
# Endopiriform nucleus                              0.824478
# Lateral amygdalar nucleus                         0.722642
# Basolateral amygdalar nucleus                     0.668548
# ...                                                    ...
# Supramammillary nucleus                           0.025810
# Tuberomammillary nucleus                          0.025188
# Dorsal cochlear nucleus                           0.685698
# Ventral cochlear nucleus                         -0.448365
# Gracile nucleus                                  -0.140803
#
# area                           Superior colliculus sensory related  \
# area
# Interposed nucleus                                       -0.376956
# Claustrum                                                 0.844600
# Endopiriform nucleus                                      0.959205
# Lateral amygdalar nucleus                                 0.647905
# Basolateral amygdalar nucleus                             0.840012
# ...                                                            ...
# Supramammillary nucleus                                  -0.185082
# Tuberomammillary nucleus                                 -0.126435
# Dorsal cochlear nucleus                                   0.610920
# Ventral cochlear nucleus                                 -0.415508
# Gracile nucleus                                          -0.150782
#
# area                           Inferior colliculus  \
# area
# Interposed nucleus                       -0.097308
# Claustrum                                 0.960931
# Endopiriform nucleus                      0.982468
# Lateral amygdalar nucleus                 0.536067
# Basolateral amygdalar nucleus             0.852890
# ...                                            ...
# Supramammillary nucleus                  -0.161820
# Tuberomammillary nucleus                 -0.421000
# Dorsal cochlear nucleus                   0.371378
# Ventral cochlear nucleus                 -0.149314
# Gracile nucleus                          -0.244947
#
# area                           Substantia nigra reticular part  ...  \
# area                                                            ...
# Interposed nucleus                                   -0.400000  ...
# Claustrum                                             0.730774  ...
# Endopiriform nucleus                                  0.891487  ...
# Lateral amygdalar nucleus                             0.893766  ...
# Basolateral amygdalar nucleus                         0.934666  ...
# ...                                                        ...  ...
# Supramammillary nucleus                               0.392792  ...
# Tuberomammillary nucleus                             -0.447214  ...
# Dorsal cochlear nucleus                               0.316228  ...
# Ventral cochlear nucleus                             -0.489898  ...
# Gracile nucleus                                      -0.400000  ...
#
# area                           Intergeniculate leaflet of the lateral geniculate complex  \
# area
# Interposed nucleus                                                     -0.200000
# Claustrum                                                              -0.275764
# Endopiriform nucleus                                                   -0.248545
# Lateral amygdalar nucleus                                              -0.223442
# Basolateral amygdalar nucleus                                          -0.359669
# ...                                                                          ...
# Supramammillary nucleus                                                -0.130931
# Tuberomammillary nucleus                                                0.745356
# Dorsal cochlear nucleus                                                -0.316228
# Ventral cochlear nucleus                                                0.000000
# Gracile nucleus                                                         1.000000
#
# area                           Ventral part of the lateral geniculate complex  \
# area
# Interposed nucleus                                                  -0.292770
# Claustrum                                                            0.726618
# Endopiriform nucleus                                                 0.769058
# Lateral amygdalar nucleus                                            0.478047
# Basolateral amygdalar nucleus                                        0.512646
# ...                                                                       ...
# Supramammillary nucleus                                             -0.191663
# Tuberomammillary nucleus                                             0.218218
# Dorsal cochlear nucleus                                              0.462910
# Ventral cochlear nucleus                                            -0.239046
# Gracile nucleus                                                      0.292770
#
# area                           Medial habenula  Lateral habenula  \
# area
# Interposed nucleus                   -0.316228          0.923950
# Claustrum                             0.719434          0.396542
# Endopiriform nucleus                  0.797733          0.037864
# Lateral amygdalar nucleus             0.679408         -0.591611
# Basolateral amygdalar nucleus         0.643514         -0.194303
# ...                                        ...               ...
# Supramammillary nucleus               0.000000         -0.553752
# Tuberomammillary nucleus             -0.078567         -0.552877
# Dorsal cochlear nucleus               0.750000         -0.020576
# Ventral cochlear nucleus             -0.387298          0.860656
# Gracile nucleus                      -0.316228         -0.403415
#
# area                           Medial mammillary nucleus  \
# area
# Interposed nucleus                             -0.453535
# Claustrum                                      -0.360492
# Endopiriform nucleus                           -0.121697
# Lateral amygdalar nucleus                       0.538791
# Basolateral amygdalar nucleus                   0.244936
# ...                                                  ...
# Supramammillary nucleus                         0.960586
# Tuberomammillary nucleus                       -0.218735
# Dorsal cochlear nucleus                        -0.464007
# Ventral cochlear nucleus                       -0.490116
# Gracile nucleus                                -0.133393
#
# area                           Supramammillary nucleus  \
# area
# Interposed nucleus                           -0.392792
# Claustrum                                    -0.234689
# Endopiriform nucleus                         -0.036050
# Lateral amygdalar nucleus                     0.596359
# Basolateral amygdalar nucleus                 0.254047
# ...                                                ...
# Supramammillary nucleus                       1.000000
# Tuberomammillary nucleus                     -0.227710
# Dorsal cochlear nucleus                      -0.414039
# Ventral cochlear nucleus                     -0.427618
# Gracile nucleus                              -0.130931
#
# area                           Tuberomammillary nucleus  \
# area
# Interposed nucleus                            -0.447214
# Claustrum                                     -0.472747
# Endopiriform nucleus                          -0.360525
# Lateral amygdalar nucleus                     -0.140921
# Basolateral amygdalar nucleus                 -0.447978
# ...                                                 ...
# Supramammillary nucleus                       -0.227710
# Tuberomammillary nucleus                       1.000000
# Dorsal cochlear nucleus                        0.235702
# Ventral cochlear nucleus                      -0.304290
# Gracile nucleus                                0.745356
#
# area                           Dorsal cochlear nucleus  \
# area
# Interposed nucleus                           -0.316228
# Claustrum                                     0.348817
# Endopiriform nucleus                          0.425928
# Lateral amygdalar nucleus                     0.298940
# Basolateral amygdalar nucleus                 0.284343
# ...                                                ...
# Supramammillary nucleus                      -0.414039
# Tuberomammillary nucleus                      0.235702
# Dorsal cochlear nucleus                       1.000000
# Ventral cochlear nucleus                     -0.387298
# Gracile nucleus                              -0.316228
#
# area                           Ventral cochlear nucleus  Gracile nucleus
# area
# Interposed nucleus                             0.979796        -0.200000
# Claustrum                                      0.084435        -0.275764
# Endopiriform nucleus                          -0.304404        -0.248545
# Lateral amygdalar nucleus                     -0.799926        -0.223442
# Basolateral amygdalar nucleus                 -0.541934        -0.359669
# ...                                                 ...              ...
# Supramammillary nucleus                       -0.427618        -0.130931
# Tuberomammillary nucleus                      -0.304290         0.745356
# Dorsal cochlear nucleus                       -0.387298        -0.316228
# Ventral cochlear nucleus                       1.000000         0.000000
# Gracile nucleus                                0.000000         1.000000
#
# [176 rows x 176 columns]

# %%
corr_matrix_unfam_ncells = cross_corr(df_unfam_cell_count)
corr_matrix_unfam_ncells
# Out:
# area                           Fastigial nucleus  Claustrum  \
# area
# Fastigial nucleus                       1.000000   0.412289
# Claustrum                               0.412289   1.000000
# Endopiriform nucleus                    0.950023   0.609418
# Lateral amygdalar nucleus               0.753992   0.225384
# Basolateral amygdalar nucleus           0.940247   0.567747
# ...                                          ...        ...
# Dorsal cochlear nucleus                -0.200000   0.664711
# Ventral cochlear nucleus               -0.171686   0.684863
# Cuneate nucleus                         1.000000   0.412289
# Spinal vestibular nucleus              -0.200000   0.664711
# Superior vestibular nucleus            -0.200000  -0.445945
#
# area                           Endopiriform nucleus  \
# area
# Fastigial nucleus                          0.950023
# Claustrum                                  0.609418
# Endopiriform nucleus                       1.000000
# Lateral amygdalar nucleus                  0.789120
# Basolateral amygdalar nucleus              0.994680
# ...                                             ...
# Dorsal cochlear nucleus                   -0.060128
# Ventral cochlear nucleus                  -0.035930
# Cuneate nucleus                            0.950023
# Spinal vestibular nucleus                 -0.060128
# Superior vestibular nucleus               -0.281743
#
# area                           Lateral amygdalar nucleus  \
# area
# Fastigial nucleus                               0.753992
# Claustrum                                       0.225384
# Endopiriform nucleus                            0.789120
# Lateral amygdalar nucleus                       1.000000
# Basolateral amygdalar nucleus                   0.824440
# ...                                                  ...
# Dorsal cochlear nucleus                        -0.436522
# Ventral cochlear nucleus                       -0.425823
# Cuneate nucleus                                 0.753992
# Spinal vestibular nucleus                      -0.436522
# Superior vestibular nucleus                     0.238103
#
# area                           Basolateral amygdalar nucleus  \
# area
# Fastigial nucleus                                   0.940247
# Claustrum                                           0.567747
# Endopiriform nucleus                                0.994680
# Lateral amygdalar nucleus                           0.824440
# Basolateral amygdalar nucleus                       1.000000
# ...                                                      ...
# Dorsal cochlear nucleus                            -0.141742
# Ventral cochlear nucleus                           -0.118201
# Cuneate nucleus                                     0.940247
# Spinal vestibular nucleus                          -0.141742
# Superior vestibular nucleus                        -0.279774
#
# area                           Basomedial amygdalar nucleus  \
# area
# Fastigial nucleus                                  0.644155
# Claustrum                                          0.599779
# Endopiriform nucleus                               0.831476
# Lateral amygdalar nucleus                          0.720222
# Basolateral amygdalar nucleus                      0.860356
# ...                                                     ...
# Dorsal cochlear nucleus                           -0.074530
# Ventral cochlear nucleus                          -0.066680
# Cuneate nucleus                                    0.644155
# Spinal vestibular nucleus                         -0.074530
# Superior vestibular nucleus                       -0.383299
#
# area                           Posterior amygdalar nucleus  \
# area
# Fastigial nucleus                                 0.563491
# Claustrum                                         0.764619
# Endopiriform nucleus                              0.777001
# Lateral amygdalar nucleus                         0.682410
# Basolateral amygdalar nucleus                     0.769648
# ...                                                    ...
# Dorsal cochlear nucleus                           0.277329
# Ventral cochlear nucleus                          0.280664
# Cuneate nucleus                                   0.563491
# Spinal vestibular nucleus                         0.277329
# Superior vestibular nucleus                      -0.104219
#
# area                           Superior colliculus sensory related  \
# area
# Fastigial nucleus                                         0.517153
# Claustrum                                                 0.926381
# Endopiriform nucleus                                      0.741005
# Lateral amygdalar nucleus                                 0.397490
# Basolateral amygdalar nucleus                             0.723307
# ...                                                            ...
# Dorsal cochlear nucleus                                   0.451828
# Ventral cochlear nucleus                                  0.465607
# Cuneate nucleus                                           0.517153
# Spinal vestibular nucleus                                 0.451828
# Superior vestibular nucleus                              -0.528040
#
# area                           Inferior colliculus  \
# area
# Fastigial nucleus                         0.070789
# Claustrum                                 0.624760
# Endopiriform nucleus                      0.369463
# Lateral amygdalar nucleus                 0.248552
# Basolateral amygdalar nucleus             0.388391
# ...                                            ...
# Dorsal cochlear nucleus                   0.310858
# Ventral cochlear nucleus                  0.299996
# Cuneate nucleus                           0.070789
# Spinal vestibular nucleus                 0.310858
# Superior vestibular nucleus              -0.409347
#
# area                           Nucleus of the brachium of the inferior colliculus  \
# area
# Fastigial nucleus                                                       0.632456
# Claustrum                                                               0.212861
# Endopiriform nucleus                                                    0.507950
# Lateral amygdalar nucleus                                               0.345101
# Basolateral amygdalar nucleus                                           0.518630
# ...                                                                          ...
# Dorsal cochlear nucleus                                                -0.316228
# Ventral cochlear nucleus                                               -0.271460
# Cuneate nucleus                                                         0.632456
# Spinal vestibular nucleus                                              -0.316228
# Superior vestibular nucleus                                            -0.316228
#
# area                           ...  Medial habenula  Lateral habenula  \
# area                           ...
# Fastigial nucleus              ...     5.855400e-01          0.285931
# Claustrum                      ...     2.832893e-01         -0.021871
# Endopiriform nucleus           ...     5.582885e-01          0.190792
# Lateral amygdalar nucleus      ...     7.358208e-01          0.170203
# Basolateral amygdalar nucleus  ...     5.344746e-01          0.237654
# ...                            ...              ...               ...
# Dorsal cochlear nucleus        ...    -1.625200e-17         -0.493881
# Ventral cochlear nucleus       ...     1.142379e-02         -0.457435
# Cuneate nucleus                ...     5.855400e-01          0.285931
# Spinal vestibular nucleus      ...    -1.625200e-17         -0.493881
# Superior vestibular nucleus    ...     5.855400e-01         -0.337919
#
# area                           Medial mammillary nucleus  \
# area
# Fastigial nucleus                               0.779911
# Claustrum                                       0.422356
# Endopiriform nucleus                            0.873036
# Lateral amygdalar nucleus                       0.685944
# Basolateral amygdalar nucleus                   0.889898
# ...                                                  ...
# Dorsal cochlear nucleus                        -0.182532
# Ventral cochlear nucleus                       -0.174821
# Cuneate nucleus                                 0.779911
# Spinal vestibular nucleus                      -0.182532
# Superior vestibular nucleus                    -0.414846
#
# area                           Supramammillary nucleus  \
# area
# Fastigial nucleus                             0.272624
# Claustrum                                     0.906403
# Endopiriform nucleus                          0.530590
# Lateral amygdalar nucleus                     0.259802
# Basolateral amygdalar nucleus                 0.497197
# ...                                                ...
# Dorsal cochlear nucleus                       0.664280
# Ventral cochlear nucleus                      0.665529
# Cuneate nucleus                               0.272624
# Spinal vestibular nucleus                     0.664280
# Superior vestibular nucleus                  -0.303342
#
# area                           Tuberomammillary nucleus  \
# area
# Fastigial nucleus                             -0.128554
# Claustrum                                      0.283550
# Endopiriform nucleus                           0.147811
# Lateral amygdalar nucleus                      0.258719
# Basolateral amygdalar nucleus                  0.204089
# ...                                                 ...
# Dorsal cochlear nucleus                       -0.018365
# Ventral cochlear nucleus                      -0.037263
# Cuneate nucleus                               -0.128554
# Spinal vestibular nucleus                     -0.018365
# Superior vestibular nucleus                   -0.238743
#
# area                           Dorsal cochlear nucleus  \
# area
# Fastigial nucleus                            -0.200000
# Claustrum                                     0.664711
# Endopiriform nucleus                         -0.060128
# Lateral amygdalar nucleus                    -0.436522
# Basolateral amygdalar nucleus                -0.141742
# ...                                                ...
# Dorsal cochlear nucleus                       1.000000
# Ventral cochlear nucleus                      0.998903
# Cuneate nucleus                              -0.200000
# Spinal vestibular nucleus                     1.000000
# Superior vestibular nucleus                  -0.200000
#
# area                           Ventral cochlear nucleus  Cuneate nucleus  \
# area
# Fastigial nucleus                             -0.171686         1.000000
# Claustrum                                      0.684863         0.412289
# Endopiriform nucleus                          -0.035930         0.950023
# Lateral amygdalar nucleus                     -0.425823         0.753992
# Basolateral amygdalar nucleus                 -0.118201         0.940247
# ...                                                 ...              ...
# Dorsal cochlear nucleus                        0.998903        -0.200000
# Ventral cochlear nucleus                       1.000000        -0.171686
# Cuneate nucleus                               -0.171686         1.000000
# Spinal vestibular nucleus                      0.998903        -0.200000
# Superior vestibular nucleus                   -0.218510        -0.200000
#
# area                           Spinal vestibular nucleus  \
# area
# Fastigial nucleus                              -0.200000
# Claustrum                                       0.664711
# Endopiriform nucleus                           -0.060128
# Lateral amygdalar nucleus                      -0.436522
# Basolateral amygdalar nucleus                  -0.141742
# ...                                                  ...
# Dorsal cochlear nucleus                         1.000000
# Ventral cochlear nucleus                        0.998903
# Cuneate nucleus                                -0.200000
# Spinal vestibular nucleus                       1.000000
# Superior vestibular nucleus                    -0.200000
#
# area                           Superior vestibular nucleus
# area
# Fastigial nucleus                                -0.200000
# Claustrum                                        -0.445945
# Endopiriform nucleus                             -0.281743
# Lateral amygdalar nucleus                         0.238103
# Basolateral amygdalar nucleus                    -0.279774
# ...                                                    ...
# Dorsal cochlear nucleus                          -0.200000
# Ventral cochlear nucleus                         -0.218510
# Cuneate nucleus                                  -0.200000
# Spinal vestibular nucleus                        -0.200000
# Superior vestibular nucleus                       1.000000
#
# [190 rows x 190 columns]

# %% [markdown]
# ## Plot cross corr matrix across groups per area on cell count

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix_control_ncells,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
ax.set_title('CONTROL')
# Out:
# Text(0.5, 1.0, 'CONTROL')

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix_fam_ncells,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
ax.set_title('FAM')
# Out:
# Text(0.5, 1.0, 'FAM')

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix_unfam_ncells,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
ax.set_title('UNFAM')
# Out:
# Text(0.5, 1.0, 'UNFAM')

# %% [markdown]
# # Calculate energy across experimental groups

# %%
df_control_energy, df_fam_energy, df_unfam_energy = \
calculate_value_across_groups(experimental_groups, dict_results_across_mice, value='energy')

# %%
df_control_energy
# Out:
#                             area    F10Control  F16Control   F11Control  \
# 48             Fastigial nucleus      0.000000         0.0     0.000000
# 49            Interposed nucleus      0.000000         0.0     0.000000
# 50               Dentate nucleus      0.000000         0.0     0.000000
# 51   Vestibulocerebellar nucleus      0.000000         0.0     0.000000
# 88                     Claustrum  61309.100832         0.0     0.000000
# ..                           ...           ...         ...          ...
# 377           Nucleus prepositus      0.000000         0.0     0.000000
# 378   Lateral vestibular nucleus      0.000000         0.0     0.000000
# 379    Medial vestibular nucleus      0.000000         0.0  4753.907832
# 380    Spinal vestibular nucleus      0.000000         0.0     0.000000
# 381  Superior vestibular nucleus      0.000000         0.0     0.000000
#
#         F1Control
# 48       0.000000
# 49       0.000000
# 50       0.000000
# 51       0.000000
# 88   79656.608352
# ..            ...
# 377      0.000000
# 378      0.000000
# 379      0.000000
# 380      0.000000
# 381  18846.974320
#
# [297 rows x 5 columns]

# %%
df_fam_energy
# Out:
#                             area         F7Fam  F15Fam        F13Fam  \
# 48             Fastigial nucleus      0.000000     0.0      0.000000
# 49            Interposed nucleus      0.000000     0.0      0.000000
# 50               Dentate nucleus      0.000000     0.0      0.000000
# 51   Vestibulocerebellar nucleus      0.000000     0.0      0.000000
# 88                     Claustrum  49049.560803     0.0  13737.829264
# ..                           ...           ...     ...           ...
# 377           Nucleus prepositus      0.000000     0.0      0.000000
# 378   Lateral vestibular nucleus      0.000000     0.0      0.000000
# 379    Medial vestibular nucleus      0.000000     0.0      0.000000
# 380    Spinal vestibular nucleus      0.000000     0.0      0.000000
# 381  Superior vestibular nucleus      0.000000     0.0      0.000000
#
#             F5Fam        F3Fam          F9Fam
# 48       0.000000     0.000000       0.000000
# 49    3644.054341     0.000000       0.000000
# 50       0.000000     0.000000       0.000000
# 51       0.000000     0.000000       0.000000
# 88   44774.302734  5080.906701  128949.383837
# ..            ...          ...            ...
# 377      0.000000     0.000000       0.000000
# 378      0.000000     0.000000       0.000000
# 379      0.000000     0.000000       0.000000
# 380      0.000000     0.000000       0.000000
# 381      0.000000     0.000000       0.000000
#
# [297 rows x 7 columns]

# %%
df_unfam_energy
# Out:
#                             area        F6Unfam       F8Unfam       F4Unfam  \
# 48             Fastigial nucleus    6674.739175      0.000000      0.000000
# 49            Interposed nucleus       0.000000      0.000000      0.000000
# 50               Dentate nucleus       0.000000      0.000000      0.000000
# 51   Vestibulocerebellar nucleus       0.000000      0.000000      0.000000
# 88                     Claustrum  146951.070482  98498.145693  20992.467179
# ..                           ...            ...           ...           ...
# 377           Nucleus prepositus       0.000000      0.000000      0.000000
# 378   Lateral vestibular nucleus       0.000000      0.000000      0.000000
# 379    Medial vestibular nucleus       0.000000      0.000000      0.000000
# 380    Spinal vestibular nucleus       0.000000      0.000000      0.000000
# 381  Superior vestibular nucleus       0.000000      0.000000  42767.214715
#
#            F2Unfam      F12Unfam  F14Unfam
# 48        0.000000      0.000000       0.0
# 49        0.000000      0.000000       0.0
# 50        0.000000      0.000000       0.0
# 51        0.000000      0.000000       0.0
# 88   190440.895680  56121.787708       0.0
# ..             ...           ...       ...
# 377       0.000000      0.000000       0.0
# 378       0.000000      0.000000       0.0
# 379       0.000000      0.000000       0.0
# 380   20870.569733      0.000000       0.0
# 381       0.000000      0.000000       0.0
#
# [297 rows x 7 columns]

# %%
df_ttest_energy = ttest_across_groups(df_control=df_control_energy,
                                      df_fam=df_fam_energy,
                                      df_unfam=df_unfam_energy)
df_ttest_energy
# Out:
#                             area pval_Control_vs_Fam pval_Control_vs_Unfam  \
# 48             Fastigial nucleus                 NaN              0.446813
# 49            Interposed nucleus            0.446813                   NaN
# 50               Dentate nucleus                 NaN                   NaN
# 51   Vestibulocerebellar nucleus                 NaN                   NaN
# 88                     Claustrum            0.868817              0.256154
# ..                           ...                 ...                   ...
# 377           Nucleus prepositus                 NaN                   NaN
# 378   Lateral vestibular nucleus                 NaN                   NaN
# 379    Medial vestibular nucleus            0.241504              0.241504
# 380    Spinal vestibular nucleus                 NaN              0.446813
# 381  Superior vestibular nucleus            0.241504              0.808745
#
#     pval_Fam_vs_Unfam
# 48           0.340893
# 49           0.340893
# 50                NaN
# 51                NaN
# 88           0.237129
# ..                ...
# 377               NaN
# 378               NaN
# 379               NaN
# 380          0.340893
# 381          0.340893
#
# [297 rows x 4 columns]

# %%
# remove rows corresponding to area that have zero cell count across all experimental groups
df_ttest_not_null_energy = df_ttest_energy.dropna(axis=0,
                                   how='all',
                                   subset=['pval_Control_vs_Fam',
                                          'pval_Control_vs_Unfam',
                                          'pval_Fam_vs_Unfam'])
df_ttest_not_null_energy
# Out:
#                             area pval_Control_vs_Fam pval_Control_vs_Unfam  \
# 48             Fastigial nucleus                 NaN              0.446813
# 49            Interposed nucleus            0.446813                   NaN
# 88                     Claustrum            0.868817              0.256154
# 89          Endopiriform nucleus            0.297035              0.192528
# 90     Lateral amygdalar nucleus            0.892731              0.334298
# ..                           ...                 ...                   ...
# 373              Cuneate nucleus            0.145877              0.193705
# 374              Gracile nucleus            0.446813                   NaN
# 379    Medial vestibular nucleus            0.241504              0.241504
# 380    Spinal vestibular nucleus                 NaN              0.446813
# 381  Superior vestibular nucleus            0.241504              0.808745
#
#     pval_Fam_vs_Unfam
# 48           0.340893
# 49           0.340893
# 88           0.237129
# 89           0.481836
# 90           0.260675
# ..                ...
# 373          0.340893
# 374          0.340893
# 379               NaN
# 380          0.340893
# 381          0.340893
#
# [210 rows x 4 columns]

# %%
# sort dataframe pvalues of control vs fam and pick the first 20
df_ttest_not_null_energy.sort_values(by='pval_Control_vs_Fam')[['area', 'pval_Control_vs_Fam']][0:20].set_index('area')
# Out:
#                                                    pval_Control_vs_Fam
# area
# Medial preoptic nucleus                                     0.00475805
# Medial amygdalar nucleus                                     0.0167212
# Cortical amygdalar area                                      0.0187642
# Bed nuclei of the stria terminalis                           0.0255039
# Tuberal nucleus                                              0.0277758
# Bed nucleus of the accessory olfactory tract                  0.037427
# Fasciola cinerea                                             0.0393707
# Ventromedial hypothalamic nucleus                            0.0450243
# Posterior auditory area                                      0.0451783
# Intercalated amygdalar nucleus                               0.0460581
# Periventricular hypothalamic nucleus posterior ...           0.0495728
# Ventral premammillary nucleus                                0.0588921
# Accessory olfactory bulb                                      0.061203
# Primary auditory area                                        0.0619462
# Fundus of striatum                                           0.0777575
# Nucleus of the brachium of the inferior colliculus           0.0812446
# Red nucleus                                                    0.08214
# Piriform-amygdalar area                                      0.0892016
# Globus pallidus internal segment                             0.0923351
# Supratrigeminal nucleus                                      0.0963715

# %%
# sort dataframe pvalues of control vs fam and pick the first 20
df_ttest_not_null_energy.sort_values(by='pval_Control_vs_Unfam')[['area', 'pval_Control_vs_Unfam']][0:20].set_index('area')
# Out:
#                                                    pval_Control_vs_Unfam
# area
# Medial preoptic nucleus                                        0.0082575
# Cortical amygdalar area                                        0.0147569
# Medial amygdalar nucleus                                       0.0199332
# Periventricular hypothalamic nucleus posterior ...             0.0253272
# Bed nuclei of the stria terminalis                             0.0255449
# Anteroventral periventricular nucleus                          0.0283798
# Ventromedial hypothalamic nucleus                               0.030372
# Anterior amygdalar area                                        0.0335083
# Nucleus of the solitary tract                                   0.034465
# Posterior amygdalar nucleus                                    0.0377828
# Intercalated amygdalar nucleus                                 0.0527148
# Medial septal complex                                          0.0583139
# Posterodorsal preoptic nucleus                                 0.0586692
# Central medial nucleus of the thalamus                         0.0691353
# Piriform-amygdalar area                                        0.0702727
# Superior colliculus sensory related                            0.0719946
# Posterior hypothalamic nucleus                                 0.0734627
# Accessory olfactory bulb                                       0.0789126
# Paraventricular hypothalamic nucleus                           0.0806453
# Supramammillary nucleus                                        0.0818104

# %%
# sort dataframe pvalues of control vs fam and pick the first 20
df_ttest_not_null_energy.sort_values(by='pval_Fam_vs_Unfam')[['area', 'pval_Fam_vs_Unfam']][0:20].set_index('area')
# Out:
#                                         pval_Fam_vs_Unfam
# area
# Fasciola cinerea                                0.0117615
# Simple lobule                                   0.0168505
# Posterior hypothalamic nucleus                  0.0202964
# Medial preoptic nucleus                         0.0207758
# Posterodorsal preoptic nucleus                  0.0253749
# Supramammillary nucleus                          0.025427
# Medial septal complex                           0.0441099
# Medial mammillary nucleus                       0.0445573
# Dorsomedial nucleus of the hypothalamus         0.0506741
# Substantia nigra reticular part                 0.0664248
# Dorsal premammillary nucleus                    0.0736462
# Bed nuclei of the stria terminalis              0.0757187
# Nucleus x                                       0.0775338
# Anterior hypothalamic nucleus                    0.077923
# Postpiriform transition area                    0.0828183
# Subparafascicular nucleus                       0.0841675
# Nucleus of reuniens                             0.0843107
# Anteroventral periventricular nucleus           0.0893282
# Supratrigeminal nucleus                         0.0895275
# Subparaventricular zone                           0.10229

# %% [markdown]
# ## Calculate cross corr matrix across experimental groups on energy

# %%
corr_matrix_control_energy = cross_corr(df_control_energy)
corr_matrix_control_energy
# Out:
# area                           Claustrum  Endopiriform nucleus  \
# area
# Claustrum                       1.000000              0.501068
# Endopiriform nucleus            0.501068              1.000000
# Lateral amygdalar nucleus       0.494959              0.895437
# Basolateral amygdalar nucleus   0.633531              0.971389
# Basomedial amygdalar nucleus    0.747957              0.948110
# ...                                  ...                   ...
# Supramammillary nucleus         0.420003              0.994199
# Tuberomammillary nucleus        0.420003              0.994199
# Cuneate nucleus                -0.504121             -0.125951
# Medial vestibular nucleus      -0.567811             -0.329289
# Superior vestibular nucleus     0.715619             -0.244651
#
# area                           Lateral amygdalar nucleus  \
# area
# Claustrum                                       0.494959
# Endopiriform nucleus                            0.895437
# Lateral amygdalar nucleus                       1.000000
# Basolateral amygdalar nucleus                   0.952353
# Basomedial amygdalar nucleus                    0.883811
# ...                                                  ...
# Supramammillary nucleus                         0.859593
# Tuberomammillary nucleus                        0.859593
# Cuneate nucleus                                 0.236140
# Medial vestibular nucleus                       0.043337
# Superior vestibular nucleus                    -0.147397
#
# area                           Basolateral amygdalar nucleus  \
# area
# Claustrum                                           0.633531
# Endopiriform nucleus                                0.971389
# Lateral amygdalar nucleus                           0.952353
# Basolateral amygdalar nucleus                       1.000000
# Basomedial amygdalar nucleus                        0.981233
# ...                                                      ...
# Supramammillary nucleus                             0.940723
# Tuberomammillary nucleus                            0.940723
# Cuneate nucleus                                    -0.067313
# Medial vestibular nucleus                          -0.262268
# Superior vestibular nucleus                        -0.065880
#
# area                           Basomedial amygdalar nucleus  \
# area
# Claustrum                                          0.747957
# Endopiriform nucleus                               0.948110
# Lateral amygdalar nucleus                          0.883811
# Basolateral amygdalar nucleus                      0.981233
# Basomedial amygdalar nucleus                       1.000000
# ...                                                     ...
# Supramammillary nucleus                            0.911755
# Tuberomammillary nucleus                           0.911755
# Cuneate nucleus                                   -0.245492
# Medial vestibular nucleus                         -0.425565
# Superior vestibular nucleus                        0.075291
#
# area                           Posterior amygdalar nucleus  \
# area
# Claustrum                                         0.687931
# Endopiriform nucleus                              0.968424
# Lateral amygdalar nucleus                         0.917455
# Basolateral amygdalar nucleus                     0.994649
# Basomedial amygdalar nucleus                      0.995500
# ...                                                    ...
# Supramammillary nucleus                           0.936661
# Tuberomammillary nucleus                          0.936661
# Cuneate nucleus                                  -0.168594
# Medial vestibular nucleus                        -0.357704
# Superior vestibular nucleus                      -0.006238
#
# area                           Superior colliculus sensory related  \
# area
# Claustrum                                                 0.467088
# Endopiriform nucleus                                      0.865345
# Lateral amygdalar nucleus                                 0.997772
# Basolateral amygdalar nucleus                             0.930208
# Basomedial amygdalar nucleus                              0.852967
# ...                                                            ...
# Supramammillary nucleus                                   0.827639
# Tuberomammillary nucleus                                  0.827639
# Cuneate nucleus                                           0.296587
# Medial vestibular nucleus                                 0.107541
# Superior vestibular nucleus                              -0.151758
#
# area                           Inferior colliculus  \
# area
# Claustrum                                 0.999131
# Endopiriform nucleus                      0.484472
# Lateral amygdalar nucleus                 0.497032
# Basolateral amygdalar nucleus             0.625066
# Basomedial amygdalar nucleus              0.736452
# ...                                            ...
# Supramammillary nucleus                   0.400550
# Tuberomammillary nucleus                  0.400550
# Cuneate nucleus                          -0.474691
# Medial vestibular nucleus                -0.535731
# Superior vestibular nucleus               0.729689
#
# area                           Nucleus of the brachium of the inferior colliculus  \
# area
# Claustrum                                                               0.970148
# Endopiriform nucleus                                                    0.276671
# Lateral amygdalar nucleus                                               0.306028
# Basolateral amygdalar nucleus                                           0.434337
# Basomedial amygdalar nucleus                                            0.565931
# ...                                                                          ...
# Supramammillary nucleus                                                 0.187378
# Tuberomammillary nucleus                                                0.187378
# Cuneate nucleus                                                        -0.511202
# Medial vestibular nucleus                                              -0.525514
# Superior vestibular nucleus                                             0.863651
#
# area                           Substantia nigra reticular part  ...  \
# area                                                            ...
# Claustrum                                            -0.567811  ...
# Endopiriform nucleus                                 -0.420258  ...
# Lateral amygdalar nucleus                            -0.755533  ...
# Basolateral amygdalar nucleus                        -0.612575  ...
# Basomedial amygdalar nucleus                         -0.561481  ...
# ...                                                        ...  ...
# Supramammillary nucleus                              -0.333333  ...
# Tuberomammillary nucleus                             -0.333333  ...
# Cuneate nucleus                                      -0.424498  ...
# Medial vestibular nucleus                            -0.333333  ...
# Superior vestibular nucleus                          -0.333333  ...
#
# area                           Intergeniculate leaflet of the lateral geniculate complex  \
# area
# Claustrum                                                              -0.025724
# Endopiriform nucleus                                                    0.702480
# Lateral amygdalar nucleus                                               0.854140
# Basolateral amygdalar nucleus                                           0.701788
# Basomedial amygdalar nucleus                                            0.551263
# ...                                                                          ...
# Supramammillary nucleus                                                 0.704982
# Tuberomammillary nucleus                                                0.704982
# Cuneate nucleus                                                         0.612421
# Medial vestibular nucleus                                               0.433669
# Superior vestibular nucleus                                            -0.569326
#
# area                           Ventral part of the lateral geniculate complex  \
# area
# Claustrum                                                            0.420003
# Endopiriform nucleus                                                 0.994199
# Lateral amygdalar nucleus                                            0.859593
# Basolateral amygdalar nucleus                                        0.940723
# Basomedial amygdalar nucleus                                         0.911755
# ...                                                                       ...
# Supramammillary nucleus                                              1.000000
# Tuberomammillary nucleus                                             1.000000
# Cuneate nucleus                                                     -0.128919
# Medial vestibular nucleus                                           -0.333333
# Superior vestibular nucleus                                         -0.333333
#
# area                           Medial habenula  Lateral habenula  \
# area
# Claustrum                             0.439753          0.715619
# Endopiriform nucleus                  0.996192         -0.244651
# Lateral amygdalar nucleus             0.912109         -0.147397
# Basolateral amygdalar nucleus         0.964979         -0.065880
# Basomedial amygdalar nucleus          0.925039          0.075291
# ...                                        ...               ...
# Supramammillary nucleus               0.993473         -0.333333
# Tuberomammillary nucleus              0.993473         -0.333333
# Cuneate nucleus                      -0.044744         -0.424498
# Medial vestibular nucleus            -0.251929         -0.333333
# Superior vestibular nucleus          -0.307792          1.000000
#
# area                           Medial mammillary nucleus  \
# area
# Claustrum                                       0.420003
# Endopiriform nucleus                            0.994199
# Lateral amygdalar nucleus                       0.859593
# Basolateral amygdalar nucleus                   0.940723
# Basomedial amygdalar nucleus                    0.911755
# ...                                                  ...
# Supramammillary nucleus                         1.000000
# Tuberomammillary nucleus                        1.000000
# Cuneate nucleus                                -0.128919
# Medial vestibular nucleus                      -0.333333
# Superior vestibular nucleus                    -0.333333
#
# area                           Supramammillary nucleus  \
# area
# Claustrum                                     0.420003
# Endopiriform nucleus                          0.994199
# Lateral amygdalar nucleus                     0.859593
# Basolateral amygdalar nucleus                 0.940723
# Basomedial amygdalar nucleus                  0.911755
# ...                                                ...
# Supramammillary nucleus                       1.000000
# Tuberomammillary nucleus                      1.000000
# Cuneate nucleus                              -0.128919
# Medial vestibular nucleus                    -0.333333
# Superior vestibular nucleus                  -0.333333
#
# area                           Tuberomammillary nucleus  Cuneate nucleus  \
# area
# Claustrum                                      0.420003        -0.504121
# Endopiriform nucleus                           0.994199        -0.125951
# Lateral amygdalar nucleus                      0.859593         0.236140
# Basolateral amygdalar nucleus                  0.940723        -0.067313
# Basomedial amygdalar nucleus                   0.911755        -0.245492
# ...                                                 ...              ...
# Supramammillary nucleus                        1.000000        -0.128919
# Tuberomammillary nucleus                       1.000000        -0.128919
# Cuneate nucleus                               -0.128919         1.000000
# Medial vestibular nucleus                     -0.333333         0.977914
# Superior vestibular nucleus                   -0.333333        -0.424498
#
# area                           Medial vestibular nucleus  \
# area
# Claustrum                                      -0.567811
# Endopiriform nucleus                           -0.329289
# Lateral amygdalar nucleus                       0.043337
# Basolateral amygdalar nucleus                  -0.262268
# Basomedial amygdalar nucleus                   -0.425565
# ...                                                  ...
# Supramammillary nucleus                        -0.333333
# Tuberomammillary nucleus                       -0.333333
# Cuneate nucleus                                 0.977914
# Medial vestibular nucleus                       1.000000
# Superior vestibular nucleus                    -0.333333
#
# area                           Superior vestibular nucleus
# area
# Claustrum                                         0.715619
# Endopiriform nucleus                             -0.244651
# Lateral amygdalar nucleus                        -0.147397
# Basolateral amygdalar nucleus                    -0.065880
# Basomedial amygdalar nucleus                      0.075291
# ...                                                    ...
# Supramammillary nucleus                          -0.333333
# Tuberomammillary nucleus                         -0.333333
# Cuneate nucleus                                  -0.424498
# Medial vestibular nucleus                        -0.333333
# Superior vestibular nucleus                       1.000000
#
# [159 rows x 159 columns]

# %%
corr_matrix_fam_energy = cross_corr(df_fam_energy)
corr_matrix_fam_energy
# Out:
# area                           Interposed nucleus  Claustrum  \
# area
# Interposed nucleus                       1.000000   0.046009
# Claustrum                                0.046009   1.000000
# Endopiriform nucleus                    -0.237470   0.958435
# Lateral amygdalar nucleus               -0.635651   0.663203
# Basolateral amygdalar nucleus           -0.428081   0.827018
# ...                                           ...        ...
# Supramammillary nucleus                 -0.386536  -0.204635
# Tuberomammillary nucleus                -0.451966  -0.401975
# Dorsal cochlear nucleus                 -0.315988   0.423378
# Ventral cochlear nucleus                 0.979253  -0.009026
# Gracile nucleus                         -0.200000  -0.270683
#
# area                           Endopiriform nucleus  \
# area
# Interposed nucleus                        -0.237470
# Claustrum                                  0.958435
# Endopiriform nucleus                       1.000000
# Lateral amygdalar nucleus                  0.831548
# Basolateral amygdalar nucleus              0.937996
# ...                                             ...
# Supramammillary nucleus                   -0.062361
# Tuberomammillary nucleus                  -0.295740
# Dorsal cochlear nucleus                    0.484955
# Ventral cochlear nucleus                  -0.291282
# Gracile nucleus                           -0.236512
#
# area                           Lateral amygdalar nucleus  \
# area
# Interposed nucleus                             -0.635651
# Claustrum                                       0.663203
# Endopiriform nucleus                            0.831548
# Lateral amygdalar nucleus                       1.000000
# Basolateral amygdalar nucleus                   0.910139
# ...                                                  ...
# Supramammillary nucleus                         0.366375
# Tuberomammillary nucleus                       -0.063636
# Dorsal cochlear nucleus                         0.512932
# Ventral cochlear nucleus                       -0.699113
# Gracile nucleus                                -0.243481
#
# area                           Basolateral amygdalar nucleus  \
# area
# Interposed nucleus                                 -0.428081
# Claustrum                                           0.827018
# Endopiriform nucleus                                0.937996
# Lateral amygdalar nucleus                           0.910139
# Basolateral amygdalar nucleus                       1.000000
# ...                                                      ...
# Supramammillary nucleus                             0.186574
# Tuberomammillary nucleus                           -0.367702
# Dorsal cochlear nucleus                             0.399454
# Ventral cochlear nucleus                           -0.509250
# Gracile nucleus                                    -0.349785
#
# area                           Basomedial amygdalar nucleus  \
# area
# Interposed nucleus                                -0.308590
# Claustrum                                          0.909152
# Endopiriform nucleus                               0.975953
# Lateral amygdalar nucleus                          0.913031
# Basolateral amygdalar nucleus                      0.952348
# ...                                                     ...
# Supramammillary nucleus                            0.115692
# Tuberomammillary nucleus                          -0.278831
# Dorsal cochlear nucleus                            0.501463
# Ventral cochlear nucleus                          -0.379002
# Gracile nucleus                                   -0.309682
#
# area                           Posterior amygdalar nucleus  \
# area
# Interposed nucleus                               -0.354472
# Claustrum                                         0.812533
# Endopiriform nucleus                              0.881073
# Lateral amygdalar nucleus                         0.876683
# Basolateral amygdalar nucleus                     0.789864
# ...                                                    ...
# Supramammillary nucleus                           0.014686
# Tuberomammillary nucleus                          0.022317
# Dorsal cochlear nucleus                           0.692076
# Ventral cochlear nucleus                         -0.394209
# Gracile nucleus                                  -0.156794
#
# area                           Superior colliculus sensory related  \
# area
# Interposed nucleus                                       -0.381335
# Claustrum                                                 0.889502
# Endopiriform nucleus                                      0.967039
# Lateral amygdalar nucleus                                 0.832023
# Basolateral amygdalar nucleus                             0.902656
# ...                                                            ...
# Supramammillary nucleus                                  -0.174960
# Tuberomammillary nucleus                                 -0.140148
# Dorsal cochlear nucleus                                   0.622540
# Ventral cochlear nucleus                                 -0.419288
# Gracile nucleus                                          -0.145491
#
# area                           Inferior colliculus  \
# area
# Interposed nucleus                       -0.067414
# Claustrum                                 0.983091
# Endopiriform nucleus                      0.976857
# Lateral amygdalar nucleus                 0.701718
# Basolateral amygdalar nucleus             0.888183
# ...                                            ...
# Supramammillary nucleus                  -0.174563
# Tuberomammillary nucleus                 -0.411018
# Dorsal cochlear nucleus                   0.389875
# Ventral cochlear nucleus                 -0.120540
# Gracile nucleus                          -0.250147
#
# area                           Substantia nigra reticular part  ...  \
# area                                                            ...
# Interposed nucleus                                   -0.411932  ...
# Claustrum                                             0.756569  ...
# Endopiriform nucleus                                  0.871823  ...
# Lateral amygdalar nucleus                             0.903961  ...
# Basolateral amygdalar nucleus                         0.978392  ...
# ...                                                        ...  ...
# Supramammillary nucleus                               0.367143  ...
# Tuberomammillary nucleus                             -0.426420  ...
# Dorsal cochlear nucleus                               0.274585  ...
# Ventral cochlear nucleus                             -0.505622  ...
# Gracile nucleus                                      -0.411932  ...
#
# area                           Intergeniculate leaflet of the lateral geniculate complex  \
# area
# Interposed nucleus                                                     -0.200000
# Claustrum                                                              -0.270683
# Endopiriform nucleus                                                   -0.236512
# Lateral amygdalar nucleus                                              -0.243481
# Basolateral amygdalar nucleus                                          -0.349785
# ...                                                                          ...
# Supramammillary nucleus                                                -0.131758
# Tuberomammillary nucleus                                                0.822509
# Dorsal cochlear nucleus                                                -0.315988
# Ventral cochlear nucleus                                                0.002699
# Gracile nucleus                                                         1.000000
#
# area                           Ventral part of the lateral geniculate complex  \
# area
# Interposed nucleus                                                  -0.298455
# Claustrum                                                            0.724046
# Endopiriform nucleus                                                 0.764006
# Lateral amygdalar nucleus                                            0.649750
# Basolateral amygdalar nucleus                                        0.581782
# ...                                                                       ...
# Supramammillary nucleus                                             -0.171088
# Tuberomammillary nucleus                                             0.338578
# Dorsal cochlear nucleus                                              0.466975
# Ventral cochlear nucleus                                            -0.234105
# Gracile nucleus                                                      0.340886
#
# area                           Medial habenula  Lateral habenula  \
# area
# Interposed nucleus                   -0.348896          0.921687
# Claustrum                             0.710302          0.349091
# Endopiriform nucleus                  0.781708          0.079277
# Lateral amygdalar nucleus             0.803779         -0.388359
# Basolateral amygdalar nucleus         0.715032         -0.129350
# ...                                        ...               ...
# Supramammillary nucleus              -0.115507         -0.540585
# Tuberomammillary nucleus             -0.066991         -0.609397
# Dorsal cochlear nucleus               0.890531         -0.005578
# Ventral cochlear nucleus             -0.433010          0.858692
# Gracile nucleus                      -0.371915         -0.396465
#
# area                           Medial mammillary nucleus  \
# area
# Interposed nucleus                             -0.439219
# Claustrum                                      -0.350480
# Endopiriform nucleus                           -0.185412
# Lateral amygdalar nucleus                       0.243724
# Basolateral amygdalar nucleus                   0.119573
# ...                                                  ...
# Supramammillary nucleus                         0.951667
# Tuberomammillary nucleus                       -0.054712
# Dorsal cochlear nucleus                        -0.473714
# Ventral cochlear nucleus                       -0.473400
# Gracile nucleus                                -0.121484
#
# area                           Supramammillary nucleus  \
# area
# Interposed nucleus                           -0.386536
# Claustrum                                    -0.204635
# Endopiriform nucleus                         -0.062361
# Lateral amygdalar nucleus                     0.366375
# Basolateral amygdalar nucleus                 0.186574
# ...                                                ...
# Supramammillary nucleus                       1.000000
# Tuberomammillary nucleus                     -0.012824
# Dorsal cochlear nucleus                      -0.381340
# Ventral cochlear nucleus                     -0.421756
# Gracile nucleus                              -0.131758
#
# area                           Tuberomammillary nucleus  \
# area
# Interposed nucleus                            -0.451966
# Claustrum                                     -0.401975
# Endopiriform nucleus                          -0.295740
# Lateral amygdalar nucleus                     -0.063636
# Basolateral amygdalar nucleus                 -0.367702
# ...                                                 ...
# Supramammillary nucleus                       -0.012824
# Tuberomammillary nucleus                       1.000000
# Dorsal cochlear nucleus                        0.078146
# Ventral cochlear nucleus                      -0.291171
# Gracile nucleus                                0.822509
#
# area                           Dorsal cochlear nucleus  \
# area
# Interposed nucleus                           -0.315988
# Claustrum                                     0.423378
# Endopiriform nucleus                          0.484955
# Lateral amygdalar nucleus                     0.512932
# Basolateral amygdalar nucleus                 0.399454
# ...                                                ...
# Supramammillary nucleus                      -0.381340
# Tuberomammillary nucleus                      0.078146
# Dorsal cochlear nucleus                       1.000000
# Ventral cochlear nucleus                     -0.387856
# Gracile nucleus                              -0.315988
#
# area                           Ventral cochlear nucleus  Gracile nucleus
# area
# Interposed nucleus                             0.979253        -0.200000
# Claustrum                                     -0.009026        -0.270683
# Endopiriform nucleus                          -0.291282        -0.236512
# Lateral amygdalar nucleus                     -0.699113        -0.243481
# Basolateral amygdalar nucleus                 -0.509250        -0.349785
# ...                                                 ...              ...
# Supramammillary nucleus                       -0.421756        -0.131758
# Tuberomammillary nucleus                      -0.291171         0.822509
# Dorsal cochlear nucleus                       -0.387856        -0.315988
# Ventral cochlear nucleus                       1.000000         0.002699
# Gracile nucleus                                0.002699         1.000000
#
# [176 rows x 176 columns]

# %%
corr_matrix_unfam_energy = cross_corr(df_unfam_energy)
corr_matrix_unfam_energy
# Out:
# area                           Fastigial nucleus  Claustrum  \
# area
# Fastigial nucleus                       1.000000   0.407469
# Claustrum                               0.407469   1.000000
# Endopiriform nucleus                    0.935606   0.623263
# Lateral amygdalar nucleus               0.739762   0.293492
# Basolateral amygdalar nucleus           0.932092   0.560407
# ...                                          ...        ...
# Dorsal cochlear nucleus                -0.200000   0.695844
# Ventral cochlear nucleus               -0.195014   0.702554
# Cuneate nucleus                         1.000000   0.407469
# Spinal vestibular nucleus              -0.200000   0.695844
# Superior vestibular nucleus            -0.200000  -0.427746
#
# area                           Endopiriform nucleus  \
# area
# Fastigial nucleus                          0.935606
# Claustrum                                  0.623263
# Endopiriform nucleus                       1.000000
# Lateral amygdalar nucleus                  0.824126
# Basolateral amygdalar nucleus              0.994247
# ...                                             ...
# Dorsal cochlear nucleus                   -0.044794
# Ventral cochlear nucleus                  -0.047012
# Cuneate nucleus                            0.935606
# Spinal vestibular nucleus                 -0.044794
# Superior vestibular nucleus               -0.291600
#
# area                           Lateral amygdalar nucleus  \
# area
# Fastigial nucleus                               0.739762
# Claustrum                                       0.293492
# Endopiriform nucleus                            0.824126
# Lateral amygdalar nucleus                       1.000000
# Basolateral amygdalar nucleus                   0.857976
# ...                                                  ...
# Dorsal cochlear nucleus                        -0.382118
# Ventral cochlear nucleus                       -0.397761
# Cuneate nucleus                                 0.739762
# Spinal vestibular nucleus                      -0.382118
# Superior vestibular nucleus                     0.128889
#
# area                           Basolateral amygdalar nucleus  \
# area
# Fastigial nucleus                                   0.932092
# Claustrum                                           0.560407
# Endopiriform nucleus                                0.994247
# Lateral amygdalar nucleus                           0.857976
# Basolateral amygdalar nucleus                       1.000000
# ...                                                      ...
# Dorsal cochlear nucleus                            -0.140957
# Ventral cochlear nucleus                           -0.143040
# Cuneate nucleus                                     0.932092
# Spinal vestibular nucleus                          -0.140957
# Superior vestibular nucleus                        -0.291259
#
# area                           Basomedial amygdalar nucleus  \
# area
# Fastigial nucleus                                  0.602150
# Claustrum                                          0.545737
# Endopiriform nucleus                               0.816362
# Lateral amygdalar nucleus                          0.815246
# Basolateral amygdalar nucleus                      0.845311
# ...                                                     ...
# Dorsal cochlear nucleus                           -0.124234
# Ventral cochlear nucleus                          -0.138702
# Cuneate nucleus                                    0.602150
# Spinal vestibular nucleus                         -0.124234
# Superior vestibular nucleus                       -0.387251
#
# area                           Posterior amygdalar nucleus  \
# area
# Fastigial nucleus                                 0.585980
# Claustrum                                         0.733940
# Endopiriform nucleus                              0.827201
# Lateral amygdalar nucleus                         0.801282
# Basolateral amygdalar nucleus                     0.820159
# ...                                                    ...
# Dorsal cochlear nucleus                           0.168869
# Ventral cochlear nucleus                          0.147807
# Cuneate nucleus                                   0.585980
# Spinal vestibular nucleus                         0.168869
# Superior vestibular nucleus                      -0.196006
#
# area                           Superior colliculus sensory related  \
# area
# Fastigial nucleus                                         0.442756
# Claustrum                                                 0.912022
# Endopiriform nucleus                                      0.710727
# Lateral amygdalar nucleus                                 0.467039
# Basolateral amygdalar nucleus                             0.678529
# ...                                                            ...
# Dorsal cochlear nucleus                                   0.485180
# Ventral cochlear nucleus                                  0.476500
# Cuneate nucleus                                           0.442756
# Spinal vestibular nucleus                                 0.485180
# Superior vestibular nucleus                              -0.529948
#
# area                           Inferior colliculus  \
# area
# Fastigial nucleus                         0.011731
# Claustrum                                 0.602762
# Endopiriform nucleus                      0.350380
# Lateral amygdalar nucleus                 0.330289
# Basolateral amygdalar nucleus             0.349520
# ...                                            ...
# Dorsal cochlear nucleus                   0.347236
# Ventral cochlear nucleus                  0.319332
# Cuneate nucleus                           0.011731
# Spinal vestibular nucleus                 0.347236
# Superior vestibular nucleus              -0.416708
#
# area                           Nucleus of the brachium of the inferior colliculus  \
# area
# Fastigial nucleus                                                       0.817565
# Claustrum                                                               0.266536
# Endopiriform nucleus                                                    0.687592
# Lateral amygdalar nucleus                                               0.474036
# Basolateral amygdalar nucleus                                           0.699198
# ...                                                                          ...
# Dorsal cochlear nucleus                                                -0.304564
# Ventral cochlear nucleus                                               -0.263370
# Cuneate nucleus                                                         0.817565
# Spinal vestibular nucleus                                              -0.304564
# Superior vestibular nucleus                                            -0.304564
#
# area                           ...  Medial habenula  Lateral habenula  \
# area                           ...
# Fastigial nucleus              ...         0.534875          0.454894
# Claustrum                      ...         0.176449         -0.000080
# Endopiriform nucleus           ...         0.519949          0.329317
# Lateral amygdalar nucleus      ...         0.745719          0.238539
# Basolateral amygdalar nucleus  ...         0.510662          0.372500
# ...                            ...              ...               ...
# Dorsal cochlear nucleus        ...        -0.147999         -0.473425
# Ventral cochlear nucleus       ...        -0.164112         -0.418471
# Cuneate nucleus                ...         0.534875          0.454894
# Spinal vestibular nucleus      ...        -0.147999         -0.473425
# Superior vestibular nucleus    ...         0.656988         -0.330206
#
# area                           Medial mammillary nucleus  \
# area
# Fastigial nucleus                               0.767276
# Claustrum                                       0.381979
# Endopiriform nucleus                            0.861455
# Lateral amygdalar nucleus                       0.755208
# Basolateral amygdalar nucleus                   0.884651
# ...                                                  ...
# Dorsal cochlear nucleus                        -0.220397
# Ventral cochlear nucleus                       -0.242295
# Cuneate nucleus                                 0.767276
# Spinal vestibular nucleus                      -0.220397
# Superior vestibular nucleus                    -0.419220
#
# area                           Supramammillary nucleus  \
# area
# Fastigial nucleus                             0.196397
# Claustrum                                     0.883932
# Endopiriform nucleus                          0.506831
# Lateral amygdalar nucleus                     0.345489
# Basolateral amygdalar nucleus                 0.462739
# ...                                                ...
# Dorsal cochlear nucleus                       0.636965
# Ventral cochlear nucleus                      0.618044
# Cuneate nucleus                               0.196397
# Spinal vestibular nucleus                     0.636965
# Superior vestibular nucleus                  -0.336926
#
# area                           Tuberomammillary nucleus  \
# area
# Fastigial nucleus                             -0.159148
# Claustrum                                      0.262479
# Endopiriform nucleus                           0.159355
# Lateral amygdalar nucleus                      0.380873
# Basolateral amygdalar nucleus                  0.200089
# ...                                                 ...
# Dorsal cochlear nucleus                       -0.008258
# Ventral cochlear nucleus                      -0.035753
# Cuneate nucleus                               -0.159148
# Spinal vestibular nucleus                     -0.008258
# Superior vestibular nucleus                   -0.205645
#
# area                           Dorsal cochlear nucleus  \
# area
# Fastigial nucleus                            -0.200000
# Claustrum                                     0.695844
# Endopiriform nucleus                         -0.044794
# Lateral amygdalar nucleus                    -0.382118
# Basolateral amygdalar nucleus                -0.140957
# ...                                                ...
# Dorsal cochlear nucleus                       1.000000
# Ventral cochlear nucleus                      0.997792
# Cuneate nucleus                              -0.200000
# Spinal vestibular nucleus                     1.000000
# Superior vestibular nucleus                  -0.200000
#
# area                           Ventral cochlear nucleus  Cuneate nucleus  \
# area
# Fastigial nucleus                             -0.195014         1.000000
# Claustrum                                      0.702554         0.407469
# Endopiriform nucleus                          -0.047012         0.935606
# Lateral amygdalar nucleus                     -0.397761         0.739762
# Basolateral amygdalar nucleus                 -0.143040         0.932092
# ...                                                 ...              ...
# Dorsal cochlear nucleus                        0.997792        -0.200000
# Ventral cochlear nucleus                       1.000000        -0.195014
# Cuneate nucleus                               -0.195014         1.000000
# Spinal vestibular nucleus                      0.997792        -0.200000
# Superior vestibular nucleus                   -0.221646        -0.200000
#
# area                           Spinal vestibular nucleus  \
# area
# Fastigial nucleus                              -0.200000
# Claustrum                                       0.695844
# Endopiriform nucleus                           -0.044794
# Lateral amygdalar nucleus                      -0.382118
# Basolateral amygdalar nucleus                  -0.140957
# ...                                                  ...
# Dorsal cochlear nucleus                         1.000000
# Ventral cochlear nucleus                        0.997792
# Cuneate nucleus                                -0.200000
# Spinal vestibular nucleus                       1.000000
# Superior vestibular nucleus                    -0.200000
#
# area                           Superior vestibular nucleus
# area
# Fastigial nucleus                                -0.200000
# Claustrum                                        -0.427746
# Endopiriform nucleus                             -0.291600
# Lateral amygdalar nucleus                         0.128889
# Basolateral amygdalar nucleus                    -0.291259
# ...                                                    ...
# Dorsal cochlear nucleus                          -0.200000
# Ventral cochlear nucleus                         -0.221646
# Cuneate nucleus                                  -0.200000
# Spinal vestibular nucleus                        -0.200000
# Superior vestibular nucleus                       1.000000
#
# [190 rows x 190 columns]

# %% [markdown]
# ## Plot cross corr matrix across groups per area on energy

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix_control_energy,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
ax.set_title('CONTROL')
# Out:
# Text(0.5, 1.0, 'CONTROL')

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix_fam_energy,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
ax.set_title('FAM')
# Out:
# Text(0.5, 1.0, 'FAM')

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix_unfam_energy,
    cmap=sns.diverging_palette(220, 10, as_cmap=True),
    vmin=-1.0, vmax=1.0,
    square=True, ax=ax)
ax.set_title('UNFAM')
# Out:
# Text(0.5, 1.0, 'UNFAM')
